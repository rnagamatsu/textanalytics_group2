# %% [markdown]
# <a href="https://colab.research.google.com/github/rnagamatsu/textanalytics_group2/blob/main/main_code_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
# !pip install ibm_watson
# !pip install openai
# !pip install google.cloud
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Collecting ibm_watson
#   Downloading ibm-watson-8.0.0.tar.gz (398 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.3/398.3 kB 6.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (2.8.2)
# Requirement already satisfied: websocket-client>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (1.8.0)
# Collecting ibm-cloud-sdk-core==3.*,>=3.3.6 (from ibm_watson)
#   Downloading ibm-cloud-sdk-core-3.20.0.tar.gz (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting urllib3<3.0.0,>=2.1.0 (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson)
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 7.5 MB/s eta 0:00:00
# Collecting PyJWT<3.0.0,>=2.8.0 (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson)
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.5.3->ibm_watson) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (2024.2.2)
# Building wheels for collected packages: ibm_watson, ibm-cloud-sdk-core
#   Building wheel for ibm_watson (pyproject.toml) ... done
#   Created wheel for ibm_watson: filename=ibm_watson-8.0.0-py3-none-any.whl size=401037 sha256=b0189fe131413ecd80982050b3a8f0c3e1a3d9334aaf90d7f809508d81b05c49
#   Stored in directory: /root/.cache/pip/wheels/3b/7f/40/3601b4f434eb462a9f46e24b9dd8c96881e6e913a18cc904f9
#   Building wheel for ibm-cloud-sdk-core (pyproject.toml) ... done
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-3.20.0-py3-none-any.whl size=101424 sha256=747961265736d65a3fd1426d25b9bec00760c0563367f9d02e6f67a5071852fe
#   Stored in directory: /root/.cache/pip/wheels/d0/1c/35/8ae2b2b46ca9f86d9edcc026eb0f1a5e8237b712ea3e1ba6c4
# Successfully built ibm_watson ibm-cloud-sdk-core
# Installing collected packages: urllib3, PyJWT, ibm-cloud-sdk-core, ibm_watson
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# Successfully installed PyJWT-2.8.0 ibm-cloud-sdk-core-3.20.0 ibm_watson-8.0.0 urllib3-2.2.1
# Collecting openai
#   Downloading openai-1.27.0-py3-none-any.whl (314 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.1/314.1 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.7 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.27.0
# Collecting google.cloud
#   Downloading google_cloud-0.34.0-py2.py3-none-any.whl (1.8 kB)
# Installing collected packages: google.cloud
# Successfully installed google.cloud-0.34.0

# %%
import requests
import pandas as pd
import numpy as np
import os
import nltk
import matplotlib.pyplot as plt
from google.cloud import translate_v2 as translate
from openai import OpenAI
from nltk.tokenize import word_tokenize
from nltk.translate.nist_score import sentence_nist
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %% [markdown]
# # Import Data

# %%
def get_urls(owner, repo, path):
    # Construct the URL for the GitHub API
    api_url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}"

    # Fetch the content of the GitHub repository
    response = requests.get(api_url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the response to extract file names, file objects, and file URLs
        names = [file['name'] for file in response.json()]
        urls = [f"https://raw.githubusercontent.com/{owner}/{repo}/main/{path}/{name}" for name in names]  # URLs to each file

        # Print the list of files and their corresponding URLs
        print("Files in the GitHub repository folder:")
        for name, url in zip(names, urls):
            print(f"{name}: {url}")

        return names, urls
    else:
        # If the request was not successful, print an error message
        print(f"Error: Failed to fetch content from GitHub repository. Status code: {response.status_code}")
        return [], []

# %%
# GitHub repository information
owner = "rnagamatsu"
repo = "textanalytics_group2"
path = "flores200_group2"

# Get the list of files in the GitHub repository folder
files_names, files_urls = get_urls(owner, repo, path)
# Out:
# Files in the GitHub repository folder:
# eng_Latn.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/eng_Latn.dev
# hin_Deva.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/hin_Deva.dev
# ind_Latn.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/ind_Latn.dev
# jpn_Jpan.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/jpn_Jpan.dev
# kor_Hang.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/kor_Hang.dev
# spa_Latn.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/spa_Latn.dev
# tha_Thai.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/tha_Thai.dev
# vie_Latn.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/vie_Latn.dev

# %%
def process_flores(files_names, files_urls):
    dfs = []

    for index, (name, url) in enumerate(zip(files_names, files_urls)):
        response = requests.get(url)
        if response.status_code == 200:
            print(f"Downloaded and processed file {index+1}/{len(files_names)}: {name}")
            text = response.text
            df_name = name[:3]
            df = pd.DataFrame(text.split('\n'), columns=[df_name])
            dfs.append(df)
        else:
            print(f"Error: Failed to download file {name}")

    # Concatenate the DataFrames along the columns axis
    if dfs:
        concatenated_df = pd.concat(dfs, axis=1)
        # Last row is empty
        concatenated_df.drop(concatenated_df.index[-1], inplace=True)
        return concatenated_df
    else:
        print("No DataFrames to concatenate.")
        return None

# %%
references = process_flores(files_names, files_urls)
# Out:
# Downloaded and processed file 1/8: eng_Latn.dev
# Downloaded and processed file 2/8: hin_Deva.dev
# Downloaded and processed file 3/8: ind_Latn.dev
# Downloaded and processed file 4/8: jpn_Jpan.dev
# Downloaded and processed file 5/8: kor_Hang.dev
# Downloaded and processed file 6/8: spa_Latn.dev
# Downloaded and processed file 7/8: tha_Thai.dev
# Downloaded and processed file 8/8: vie_Latn.dev

# %%
# Rename columns to universal language code
references.columns = ['en', 'hi', 'id', 'ja', 'ko', 'es', 'th', 'vi']

# %%
# Reduce the size of the data for the analysis
references = references[:50]

# %%
references
# Out:
#                                                    en  \
# 0   On Monday, scientists from the Stanford Univer...
# 1   Lead researchers say this may bring early dete...
# 2   The JAS 39C Gripen crashed onto a runway at ar...
# 3   The pilot was identified as Squadron Leader Di...
# 4   Local media reports an airport fire vehicle ro...
# 5   28-year-old Vidal had joined Barça three seaso...
# 6   Since moving to the Catalan-capital, Vidal had...
# 7   The protest started around 11:00 local time (U...
# 8   Just after 11:00, protesters blocked traffic o...
# 9   At 11:20, the police asked the protesters to m...
# 10  Around 11:29, the protest moved up Whitehall, ...
# 11  Nadal's head to head record against the Canadi...
# 12  He recently lost against Raonic in the Brisban...
# 13  Nadal bagged 88% net points in the match winni...
# 14  After the match, King of Clay said, "I am just...
#
#                                                    hi  \
# 0   सोमवार को, स्टैनफ़ोर्ड यूनिवर्सिटी स्कूल ऑफ़ म...
# 1   शोधकर्ताओं ने कहा है कि यह अल्प आय वाले देशों ...
# 2   स्थानीय समय (0230 UTC) के मुताबिक करीब 9:30 बज...
# 3   पायलट की पहचान स्क्वाड्रन लीडर दिलोकृत पटावी क...
# 4   स्थानीय मीडिया ने बताया है कि कार्रवाई करने के...
# 5   28 वर्षीय विडाल तीन सीजन पहले सेविला से बारका ...
# 6   कातलान की राजधानी (बार्सिलोना) में जाने के बाद...
# 7   व्हाइटहॉल पर लगभग 11:00 बजे स्थानीय समय (यूटीस...
# 8   ठीक 11:00 बजे के बाद, व्हाइटहॉल में उत्तर की ओ...
# 9   11:20 पर, पुलिस ने प्रदर्शनकारियों को यह कहते ...
# 10  11:29 बजे के आस-पास, विरोध करने वाले लोग व्हाइ...
# 11      कनाडियन के खिलाफ नडाल का सीधा रिकॉर्ड 7-2 है।
# 12  वे हाल ही में ब्रिस्बेन ओपन में रोनिक के खिलाफ...
# 13  फ़र्स्ट सर्व में नडाल को 76 मैच विनिंग पॉइंट्स...
# 14  मैच के बाद, क्ले के राजा ने कहा, “मैं सबसे महत...
#
#                                                    id  \
# 0   Ilmuwan dari Stanford University School of Med...
# 1   Ketua peneliti mengatakan bahwa diagnosis ini ...
# 2   JAS 39C Gripen jatuh ke landasan pacu sekitar ...
# 3   Pilot tersebut diidentifikasi sebagai Pemimpin...
# 4   Media lokal melaporkan sebuah kendaraan pemada...
# 5   Vidal yang berusia 28 tahun bergabung dengan B...
# 6   Sejak menetap di ibu kota Catalan, Vidal sudah...
# 7   Protes dimulai sekitar pukul 11.00 waktu setem...
# 8   Pengunjuk rasa tepat setelah pukul 11.00 membl...
# 9   Pada pukul 11.20, polisi meminta para pengunju...
# 10  Sekitar pukul 11.29, para pengunjuk rasa berpi...
# 11  Adu rekor Nadal melawan petenis asal Kanada te...
# 12  Baru-baru ini dia kalah melawan Raonic di Bris...
# 13  Nadal mengantongi 88% poin bersih dalam laga i...
# 14  "Seusai pertandingan, Raja Tanah Liat berkata,...
#
#                                                    ja  \
# 0   月曜日にスタンフォード大学医学部の科学者たちは、細胞を種類別に分類できる新しい診断ツールを発...
# 1   主任研究者は、これは低所得国における患者の癌、結核、HIV、マラリアの早期発見につながる可能...
# 2   JAS 39Cグリペンは現地時間の午前9時30分頃（UTC 0230）に滑走路に墜落して爆発...
# 3                操縦士は中隊長のディロクリット・パタヴェー氏であることが確認されました。
# 4               地元メディアの報道によると、空港の消防車が対応中に横転したということです。
# 5          28歳のビダル選手は、3シーズン前にセビージャから移籍してバルサに所属していました。
# 6                カタルーニャの州都に移って以来、ビダルはクラブで49試合に出場しました。
# 7   抗議行動は、現地時間11:00（UTC+1）頃にホワイトホール通りで始まり、首相官邸があるダ...
# 8            11時すぎちょうどに抗議者たちはホワイトホールの北行き車両の交通を遮断しました。
# 9   11時20分になると、警察は抗議する権利と交通量のバランスを弁える必要があると告げて、抗議者...
# 10  11時29分頃、デモ隊は英国政府に向かい、トラファルガー広場を通り過ぎて、ストランド街沿いに...
# 11                                ナダルの対カナダ戦の戦績は7-2です。
# 12                      最近では、ブリスベン・オープンでラオニッチに敗れています。
# 13    試合中にナダルはファーストサーブで76ポイントを奪い、88%のネットポイントを獲得しています。
# 14  試合後にキング・オブ・クレーは、「最も重要なイベントの決勝に戻ってきたことに興奮している。こ...
#
#                                                    ko  \
# 0   스탠포드 의과대학 연구진은 지난 월요일 세포를 유형별로 분류할 수 있는 새로운 진단...
# 1   수석 연구진들은 이것이 선진국 대비 절반의 생존율을 보이는 저소득 국가들의 환자들에...
# 2   현지 시간으로 약 아침 9시 30분(0230 UTC)에 JAS 39C 그리펜이 활주...
# 3                     그 조종사는 비행 중대장 딜로크리트 패타비로 확인되었다.
# 4          현지 언론은 공항 소방차가 사고에 대응하는 도중에 전복되었다고 보도했습니다.
# 5            28세인 비달은 3년 전 세비야 FC에서 FC 바르셀로나에 합류했습니다.
# 6                바르셀로나로 이적한 후 비달은 클럽을 위해 49경기를 뛰었습니다.
# 7   시위는 총리의 공식 거주지인 다우닝가의 경찰이 경비를 서는 입구 맞은편 화이트홀에서...
# 8   11시가 막 지난 후, 시위대는 화이트홀에 있는 북쪽으로 향하는 마차들의 교통을 막았다.
# 9   11시 20분에 경찰이 시위대에게 보도로 돌아가도록 요청했으며, 시위할 권리와 증가...
# 10  11시 29분 경, 시위대는 스트랜드를 따라 트라팔가 광장을 지나 화이트 홀로 입성...
# 11                 나달과 이 캐나다 선수와의 정면 대결 기록은 7 대 2입니다.
# 12  그는 최근 브리즈번 오픈(Brisbane Open) 경기에서 라오니치(Raonic)...
# 13          나달은 첫 서브에서 76점을 획득하며 88%의 네트 포인트를 달성했습니다.
# 14  경기가 끝난 후 클레이의 왕은 “가장 중요한 종목의 마지막 라운드에 복귀한 것만으로...
#
#                                                    es  \
# 0   El lunes, los científicos de la facultad de me...
# 1   Los principales investigadores principales sos...
# 2   El JAS 39C Gripen impactó contra una pista cer...
# 3   Se identificó al piloto como Dilokrit Pattavee...
# 4   La prensa local informó que una patrulla de bo...
# 5   Vidal, de 28 años de edad y procedente del Sev...
# 6   Desde su mudanza a la capital catalana, Vidal ...
# 7   La manifestación inició cerca de las 11:00 hor...
# 8   Apenas pasadas las 11:00 h, los integrantes de...
# 9   A las 11:20, la policía solicitó a los manifes...
# 10  Cerca de las 11:29, la manifestación se abrió ...
# 11  El récord mano a mano de Nadal contra el canad...
# 12  Fue derrotado, hace poco, por Raonic en el Bri...
# 13  En el partido, Nadal acumuló un 88% de puntos ...
# 14  Después del partido, el Rey del Polvo declaró:...
#
#                                                    th  \
# 0   เมื่อวันจันทร์ที่ผ่านมา นักวิทยาศาสตร์จากโรงเร...
# 1   นักวิจัยชั้นนำกล่าวว่าสิ่งนี้อาจทำให้มีการตรวจ...
# 2   JAS 39C Gripen ตกลงบนรันเวย์เมื่อเวลาประมาณ 09...
# 3   นักบินคนดังกล่าวถูกระบุว่าเป็นนาวาอากาศตรีดิลก...
# 4   ผู้สื่อข่าวท้องถิ่นรายงานว่ารถดับเพลิงประจำสนา...
# 5   วิดัลวัย 28 ปี ย้ายจากเซบีญ่ามาเข้าร่วมกับบาร์...
# 6   นับตั้งแต่ย้ายมาที่เมืองหลวงของกาตาลุญญา วิดัล...
# 7   การประท้วงเริ่มขึ้นประมาณ 11.00 น. ตามเวลาท้อง...
# 8   หลังเวลา 11.00 น. พอดิบพอดี ผู้ประท้วงปิดกั้นก...
# 9   เมื่อเวลา 11.20 น. ตำรวจได้ขอให้ผู้ประท้วงย้าย...
# 10  เมื่อประมาณ 11.29 น. การประท้วงได้เคลื่อนตัวจา...
# 11  สถิติการแข่งเฮด-ทู-เฮดของนาดาลกับผู้เล่นชาวแคน...
# 12  เขาเพิ่งพ่ายแพ้ราโอนิกเมื่อไม่นานมานี้ในบริสเบ...
# 13  นาดาลเก็บคะแนนไป 88% ถ้วนในการแข่งขัน ชนะด้วย ...
# 14  หลังจบการแข่งขัน ราชาคอร์ตดินกล่าวว่า "ผมตื่นเ...
#
#                                                    vi
# 0   Vào hôm thứ Hai, các nhà khoa học thuộc Trường...
# 1   Các nhà nghiên cứu chính nói rằng điều này có ...
# 2   Chiếc JAS 39C Gripen đâm xuống đường băng vào ...
# 3   Viên phi công được xác định là Chỉ huy đội bay...
# 4   Truyền thông địa phương đưa tin một phương tiệ...
# 5   Ba mùa trước, Vidal đã rời Sevilla để gia nhập...
# 6   Từ khi chuyển đến thủ phủ của xứ Catalan, Vida...
# 7   Cuộc biểu tình bắt đầu vào khoảng 11:00 giờ sá...
# 8   Ngay sau 11 giờ những người biểu tình đã chặn ...
# 9   Vào lúc 11:20, cảnh sát đã yêu cầu người biểu ...
# 10  Khoảng 11 giờ 29 phút, nhóm biểu tình di chuyể...
# 11  Thành tích đối đầu của Nadal trước đối thủ ngư...
# 12  Gần đây anh ấy đã thua Raonic ở giải Brisbane ...
# 13  Nadal bỏ túi 88% số điểm lên lưới trong trận đ...
# 14  Sau trận đấu, Ông vua sân đất nện nói rằng “Tô...

# %% [markdown]
# # Translation

# %% [markdown]
# ### Google Translate

# %%
# Set the path to your service account key file
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "ta-msba-group-2-e04caadf49d8.json"

# Initialize the Translate API client
translator = translate.Client()

# %%
def google_translate_df(input_df, target_language):
    translated_df = pd.DataFrame()

    for col in input_df.columns:
        translated_col = []
        for cell in input_df[col]:
            # Translate each cell using Google Translate
            translation = translator.translate(cell, target_language=target_language)
            translated_text = translation['translatedText']
            translated_col.append(translated_text)
        translated_df[col] = translated_col

    return translated_df

# %%
google_candidates = google_translate_df(references.drop(columns=['en']), "en")

# %%
# Print the resulting DataFrame
google_candidates
# Out:
#                                                    hi  \
# 0   On Monday, scientists at Stanford University S...
# 1   Researchers say this could help easily identif...
# 2   At around 9:30 am local time (0230 UTC), the J...
# 3   The pilot was identified as Squadron Leader Di...
# 4   Local media has reported that the airport&#39;...
# 5   Vidal, 28, joined Barca from Sevilla three sea...
# 6   Since moving to the Catalan capital (Barcelona...
# 7   The protest began at around 11:00 am local tim...
# 8   Just after 11:00 a.m., northbound traffic on W...
# 9   At 11:20, police asked protesters to return to...
# 10  Around 11:29 am, protesters headed down Whiteh...
# 11  Nadal has a 7-2 head-to-head record against th...
# 12   He recently lost to Raonic at the Brisbane Open.
# 13  Nadal got 88% net points out of 76 match winni...
# 14  After the match, the King of Clay said, “I&#39...
#
#                                                    id  \
# 0   Scientists from Stanford University School of ...
# 1   The lead researcher said that this diagnosis c...
# 2   The JAS 39C Gripen crashed onto the runway at ...
# 3   The pilot was identified as Squadron Leader Di...
# 4   Local media reported that a fire extinguisher ...
# 5   The 28-year-old Vidal joined BarÃ§a three seas...
# 6   Since settling in the Catalan capital, Vidal h...
# 7   The protest began at around 11:00 local time (...
# 8   Protesters just after 11am blocked northbound ...
# 9   At 11:20 a.m., police asked the protesters to ...
# 10  At around 11.29am, the protesters moved down W...
# 11  Nadal&#39;s record against the Canadian tennis...
# 12  Recently he lost against Raonic at the Brisban...
# 13  Nadal pocketed 88% of the net points in this m...
# 14  &quot;After the match, the King of Clay said, ...
#
#                                                    ja  \
# 0   Scientists at the Stanford University School o...
# 1   Lead researchers say this could lead to earlie...
# 2   The JAS 39C Gripen crashed on the runway and e...
# 3   The pilot was identified as Squadron Leader Dh...
# 4   Local media reports said an airport fire truck...
# 5   The 28-year-old Vidal joined Barca from Sevill...
# 6   Since moving to the Catalan capital, Vidal has...
# 7   The protest began at around 11:00 local time (...
# 8   Just after 11am, protesters blocked northbound...
# 9   At 11:20 p.m., police asked protesters to retu...
# 10  At about 11.29pm the protesters headed towards...
# 11          Nadal&#39;s record against Canada is 7-2.
# 12  Most recently, he lost to Raonic at the Brisba...
# 13  Nadal won 76 points with his first serve durin...
# 14  After the match the King of Clay said: &quot;I...
#
#                                                    ko  \
# 0   Researchers at Stanford University School of M...
# 1   Lead researchers explain that this could lead ...
# 2   At approximately 9:30 am local time (0230 UTC)...
# 3   The pilot was identified as Squadron Leader Di...
# 4   Local media reported that the airport fire tru...
# 5   Vidal, 28, joined FC Barcelona from Sevilla FC...
# 6   After moving to Barcelona, Vidal played 49 gam...
# 7   The protest began around 11:00 local time (UTC...
# 8   Just after 11 o&#39;clock, protesters blocked ...
# 9   At 11:20 police asked protesters to return to ...
# 10  At around 11:29, the protesters followed the S...
# 11  Nadal&#39;s head-to-head record against the Ca...
# 12  He recently lost to Raonic in a match at the B...
# 13  Nadal won 76 points on his first serve, achiev...
# 14  “I’m just happy to be back in the final round ...
#
#                                                    es  \
# 0   On Monday, scientists at Stanford University S...
# 1   Leading senior researchers argue that this may...
# 2   The JAS 39C Gripen hit a runway around 9:30 a....
# 3   The pilot was identified as Dilokrit Pattavee,...
# 4   The local press reported that an airport fire ...
# 5   Vidal, 28 years old and from Sevilla, joined B...
# 6   Since moving to the Catalan capital, Vidal has...
# 7   The demonstration began around 11:00 local tim...
# 8   Just after 11:00 a.m., members of the demonstr...
# 9   At 11:20, police asked protesters to move back...
# 10  At around 11:29, the demonstration made its wa...
# 11  Nadal&#39;s head-to-head record against the Ca...
# 12  He was recently defeated by Raonic at the Bris...
# 13  In the match, Nadal accumulated 88% net points...
# 14  After the match, the King of Dust stated: “I a...
#
#                                                    th  \
# 0   last Monday Scientists at Stanford University ...
# 1   Leading researchers say this could allow for e...
# 2   The JAS 39C Gripen crashed onto the runway at ...
# 3   The pilot was identified as Wing Commander Dil...
# 4   Local reporters reported that airport fire tru...
# 5   Vidal, 28, joined Barca from Sevilla three sea...
# 6   Since moving to the Catalan capital Vidal has ...
# 7   The protest began around 11:00 AM local time (...
# 8   Just after 11 a.m., protesters blocked traffic...
# 9   At 11:20 a.m., police asked protesters to move...
# 10  At about 11:29 a.m. the protest moved from Whi...
# 11  Nadal&#39;s head-to-head record against Canadi...
# 12  He recently defeated Raonic in the Brisbane Open.
# 13  Nadal took 88% of the match&#39;s points, winn...
# 14  After the competition said the clay court king...
#
#                                                    vi
# 0   On Monday, scientists at Stanford University S...
# 1   The lead researchers say this could help early...
# 2   The JAS 39C Gripen crashed into the runway at ...
# 3   The pilot was identified as Flight Commander D...
# 4   Local media reported that an airport firefight...
# 5   Three seasons ago, Vidal left Sevilla to join ...
# 6   Since moving to the Catalan capital, Vidal has...
# 7   The protest began at around 11:00 a.m. local t...
# 8   Just after 11am protesters blocked traffic on ...
# 9   At 11:20, police asked protesters to retreat t...
# 10  At around 11:29 a.m., the protest group moved ...
# 11  Nadal&#39;s head-to-head record against this C...
# 12    He recently lost to Raonic in the Brisbane Open
# 13  Nadal pocketed 88% of the points at the net in...
# 14  After the match, the King of Clay said, “I&#39...

# %% [markdown]
# ### IBM Watson Language Translator

# %%
# Defining API key and URL
with open('ibm_api.txt', 'r') as file:
    ibm_api_key = file.read()

url = 'https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/b0153ef1-fe8f-450d-b691-9abba034bcdd'

# Authenticating the API key
authenticator = IAMAuthenticator(apikey=ibm_api_key)

# Creating the Language Translator object
ibm_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)

# Setting the service URL
ibm_translator.set_service_url(url)
# Out:
#             On 10 June 2023, IBM announced the deprecation of the Natural Language Translator service.
#             The service will no longer be available from 8 August 2022. As of 10 June 2024, the service will reach its End of Support
#             date. As of 10 December 2024, the service will be withdrawn entirely and will no longer be
#             available to any customers.

# %%
def ibm_translate_df(input_df, target_language):
    translated_df = pd.DataFrame()

    for col in input_df.columns:
        translated_col = []
        model = col + "-" + target_language
        for cell in input_df[col]:
            # Translate each cell using Google Translate
            translation = ibm_translator.translate(
                            text = cell,
                            model_id = model
                        ).get_result()
            translated_text = translation['translations'][0]['translation']
            translated_col.append(translated_text)
        translated_df[col] = translated_col

    return translated_df

# %%
ibm_candidates = ibm_translate_df(references.drop(columns=['en']), "en")

# %% [markdown]
# ### ChatGPT

# %%
with open('chat_gpt_api.txt', 'r') as file:
    gpt_api_key = file.read()

client = OpenAI(api_key=gpt_api_key)

# %%
def chatgpt_translate_df(input_df, target_language):
    translated_df = pd.DataFrame()
    for col in input_df.columns:
        translated_col = []
        for cell in input_df[col]:
            # Translation request to OpenAI using GPT4
            response = client.chat.completions.create(
                model="gpt-4", # Change to "gpt-3.5-turbo" to run on GPT3.5
                messages=[
                    {"role": "user", "content": f"Translate the following text to {target_language}: {cell}"}
                ],
                stream=True
            )
            # Processing the streaming response
            translated_text = ''
            for chunk in response:
                if chunk.choices[0].delta.content is not None:
                    translated_text += chunk.choices[0].delta.content
            translated_col.append(translated_text)
        translated_df[col] = translated_col

    return translated_df

# %%
chatgpt_candidates = chatgpt_translate_df(references.drop(columns=['eng']), "English")

# %% [markdown]
# # Tokenization

# %%
# Ensure NLTK is downloaded
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
references_tokenized = [word_tokenize(sentence) for sentence in references['en']]

# %%
def tokenize_dataframe(input_df):
    # Create a new DataFrame for tokenized strings
    tokenized_df = pd.DataFrame()

    # Tokenize strings in all columns and add them to the tokenized_df
    for col in input_df.columns:
        tokenized_df[col] = input_df[col].apply(lambda x: word_tokenize(x))

    return tokenized_df

# %%
google_candidates_tokenized = tokenize_dataframe(google_candidates)

# %%
chatgpt_candidates_tokenized = tokenize_dataframe(chatgpt_candidates)

# %%
ibm_candidates_tokenized = tokenize_dataframe(ibm_candidates)

# %%
google_candidates_tokenized
# Out:
#                                                    hi  \
# 0   [On, Monday, ,, scientists, at, Stanford, Univ...
# 1   [Researchers, say, this, could, help, easily, ...
# 2   [At, around, 9:30, am, local, time, (, 0230, U...
# 3   [The, pilot, was, identified, as, Squadron, Le...
# 4   [Local, media, has, reported, that, the, airpo...
# 5   [Vidal, ,, 28, ,, joined, Barca, from, Sevilla...
# 6   [Since, moving, to, the, Catalan, capital, (, ...
# 7   [The, protest, began, at, around, 11:00, am, l...
# 8   [Just, after, 11:00, a.m., ,, northbound, traf...
# 9   [At, 11:20, ,, police, asked, protesters, to, ...
# 10  [Around, 11:29, am, ,, protesters, headed, dow...
# 11  [Nadal, has, a, 7-2, head-to-head, record, aga...
# 12  [He, recently, lost, to, Raonic, at, the, Bris...
# 13  [Nadal, got, 88, %, net, points, out, of, 76, ...
# 14  [After, the, match, ,, the, King, of, Clay, sa...
#
#                                                    id  \
# 0   [Scientists, from, Stanford, University, Schoo...
# 1   [The, lead, researcher, said, that, this, diag...
# 2   [The, JAS, 39C, Gripen, crashed, onto, the, ru...
# 3   [The, pilot, was, identified, as, Squadron, Le...
# 4   [Local, media, reported, that, a, fire, exting...
# 5   [The, 28-year-old, Vidal, joined, BarÃ§a, thre...
# 6   [Since, settling, in, the, Catalan, capital, ,...
# 7   [The, protest, began, at, around, 11:00, local...
# 8   [Protesters, just, after, 11am, blocked, north...
# 9   [At, 11:20, a.m., ,, police, asked, the, prote...
# 10  [At, around, 11.29am, ,, the, protesters, move...
# 11  [Nadal, &, #, 39, ;, s, record, against, the, ...
# 12  [Recently, he, lost, against, Raonic, at, the,...
# 13  [Nadal, pocketed, 88, %, of, the, net, points,...
# 14  [&, quot, ;, After, the, match, ,, the, King, ...
#
#                                                    ja  \
# 0   [Scientists, at, the, Stanford, University, Sc...
# 1   [Lead, researchers, say, this, could, lead, to...
# 2   [The, JAS, 39C, Gripen, crashed, on, the, runw...
# 3   [The, pilot, was, identified, as, Squadron, Le...
# 4   [Local, media, reports, said, an, airport, fir...
# 5   [The, 28-year-old, Vidal, joined, Barca, from,...
# 6   [Since, moving, to, the, Catalan, capital, ,, ...
# 7   [The, protest, began, at, around, 11:00, local...
# 8   [Just, after, 11am, ,, protesters, blocked, no...
# 9   [At, 11:20, p.m., ,, police, asked, protesters...
# 10  [At, about, 11.29pm, the, protesters, headed, ...
# 11  [Nadal, &, #, 39, ;, s, record, against, Canad...
# 12  [Most, recently, ,, he, lost, to, Raonic, at, ...
# 13  [Nadal, won, 76, points, with, his, first, ser...
# 14  [After, the, match, the, King, of, Clay, said,...
#
#                                                    ko  \
# 0   [Researchers, at, Stanford, University, School...
# 1   [Lead, researchers, explain, that, this, could...
# 2   [At, approximately, 9:30, am, local, time, (, ...
# 3   [The, pilot, was, identified, as, Squadron, Le...
# 4   [Local, media, reported, that, the, airport, f...
# 5   [Vidal, ,, 28, ,, joined, FC, Barcelona, from,...
# 6   [After, moving, to, Barcelona, ,, Vidal, playe...
# 7   [The, protest, began, around, 11:00, local, ti...
# 8   [Just, after, 11, o, &, #, 39, ;, clock, ,, pr...
# 9   [At, 11:20, police, asked, protesters, to, ret...
# 10  [At, around, 11:29, ,, the, protesters, follow...
# 11  [Nadal, &, #, 39, ;, s, head-to-head, record, ...
# 12  [He, recently, lost, to, Raonic, in, a, match,...
# 13  [Nadal, won, 76, points, on, his, first, serve...
# 14  [“, I, ’, m, just, happy, to, be, back, in, th...
#
#                                                    es  \
# 0   [On, Monday, ,, scientists, at, Stanford, Univ...
# 1   [Leading, senior, researchers, argue, that, th...
# 2   [The, JAS, 39C, Gripen, hit, a, runway, around...
# 3   [The, pilot, was, identified, as, Dilokrit, Pa...
# 4   [The, local, press, reported, that, an, airpor...
# 5   [Vidal, ,, 28, years, old, and, from, Sevilla,...
# 6   [Since, moving, to, the, Catalan, capital, ,, ...
# 7   [The, demonstration, began, around, 11:00, loc...
# 8   [Just, after, 11:00, a.m., ,, members, of, the...
# 9   [At, 11:20, ,, police, asked, protesters, to, ...
# 10  [At, around, 11:29, ,, the, demonstration, mad...
# 11  [Nadal, &, #, 39, ;, s, head-to-head, record, ...
# 12  [He, was, recently, defeated, by, Raonic, at, ...
# 13  [In, the, match, ,, Nadal, accumulated, 88, %,...
# 14  [After, the, match, ,, the, King, of, Dust, st...
#
#                                                    th  \
# 0   [last, Monday, Scientists, at, Stanford, Unive...
# 1   [Leading, researchers, say, this, could, allow...
# 2   [The, JAS, 39C, Gripen, crashed, onto, the, ru...
# 3   [The, pilot, was, identified, as, Wing, Comman...
# 4   [Local, reporters, reported, that, airport, fi...
# 5   [Vidal, ,, 28, ,, joined, Barca, from, Sevilla...
# 6   [Since, moving, to, the, Catalan, capital, Vid...
# 7   [The, protest, began, around, 11:00, AM, local...
# 8   [Just, after, 11, a.m., ,, protesters, blocked...
# 9   [At, 11:20, a.m., ,, police, asked, protesters...
# 10  [At, about, 11:29, a.m., the, protest, moved, ...
# 11  [Nadal, &, #, 39, ;, s, head-to-head, record, ...
# 12  [He, recently, defeated, Raonic, in, the, Bris...
# 13  [Nadal, took, 88, %, of, the, match, &, #, 39,...
# 14  [After, the, competition, said, the, clay, cou...
#
#                                                    vi
# 0   [On, Monday, ,, scientists, at, Stanford, Univ...
# 1   [The, lead, researchers, say, this, could, hel...
# 2   [The, JAS, 39C, Gripen, crashed, into, the, ru...
# 3   [The, pilot, was, identified, as, Flight, Comm...
# 4   [Local, media, reported, that, an, airport, fi...
# 5   [Three, seasons, ago, ,, Vidal, left, Sevilla,...
# 6   [Since, moving, to, the, Catalan, capital, ,, ...
# 7   [The, protest, began, at, around, 11:00, a.m.,...
# 8   [Just, after, 11am, protesters, blocked, traff...
# 9   [At, 11:20, ,, police, asked, protesters, to, ...
# 10  [At, around, 11:29, a.m., ,, the, protest, gro...
# 11  [Nadal, &, #, 39, ;, s, head-to-head, record, ...
# 12  [He, recently, lost, to, Raonic, in, the, Bris...
# 13  [Nadal, pocketed, 88, %, of, the, points, at, ...
# 14  [After, the, match, ,, the, King, of, Clay, sa...

# %% [markdown]
# # Evaluation

# %%
def compute_nist_score(references, candidates_df):
    # Initialize an empty DataFrame to store the NIST scores
    nist_df = pd.DataFrame()

    # Iterate over the specified columns
    for col in candidates_df.columns:
        # Compute NIST score for each pair of sentences in the corresponding columns
        nist_scores = []
        for sent1, sent2 in zip(references, candidates_df[col]):
            nist_score = sentence_nist([sent1], sent2)
            nist_scores.append(nist_score)

        # Add NIST scores to the DataFrame
        nist_df[col] = nist_scores

        # Format the numbers as decimals
        nist_df = nist_df.applymap(lambda x: round(x, 3))

    return nist_df

# %%
google_nist = compute_nist_score(references_tokenized, google_candidates_tokenized)

# %%
chatgpt_nist = compute_nist_score(references_tokenized, chatgpt_candidates_tokenized)

# %%
ibm_nist = compute_nist_score(references_tokenized, ibm_candidates_tokenized)

# %%
ibm_nist
# Out:
#        hi     id     ja     ko     es     th     vi
# 0   3.605  3.112  2.759  2.501  3.362  3.529  3.575
# 1   2.999  3.271  2.757  3.215  3.695  2.793  3.632
# 2   2.828  3.525  3.205  2.833  3.777  2.016  3.846
# 3   2.416  3.322  0.949  1.107  2.658  1.208  2.044
# 4   1.687  1.687  0.896  2.049  2.091  1.024  1.195
# 5   2.390  2.758  1.930  1.494  2.482  1.930  1.344
# 6   2.492  2.118  2.335  3.038  2.628  2.335  3.116
# 7   2.689  2.489  1.656  1.824  2.021  2.143  2.672
# 8   1.777  2.031  1.692  1.202  1.333  2.538  1.904
# 9   2.842  2.747  2.856  3.148  3.204  3.050  2.824
# 10  1.863  3.136  2.732  1.845  3.145  2.727  3.005
# 11  2.210  1.792  1.344  1.280  2.181  1.494  1.870
# 12  2.114  2.325  1.022  2.466  1.789  2.325  2.990
# 13  2.228  2.868  2.101  1.743  2.756  2.728  2.218
# 14  3.495  3.242  3.816  2.784  3.505  3.474  3.038

# %%
google_nist
# Out:
#        hi     id     ja     ko     es     th     vi
# 0   4.905  3.957  3.297  2.860  4.133  3.958  4.380
# 1   3.468  3.490  4.372  3.481  3.588  4.173  3.875
# 2   3.525  4.006  3.722  3.979  3.949  3.059  3.846
# 3   2.990  3.322  2.658  2.658  2.416  2.325  2.658
# 4   1.434  1.898  2.151  1.673  1.280  1.103  1.870
# 5   2.689  2.987  2.841  2.049  2.390  2.689  1.344
# 6   2.829  2.010  2.628  3.038  3.116  2.552  2.872
# 7   2.908  3.420  3.086  3.568  2.131  2.710  3.126
# 8   2.991  1.896  2.709  2.115  2.464  2.792  2.862
# 9   3.170  3.565  3.175  2.224  3.265  3.455  2.499
# 10  3.113  3.621  3.325  2.876  3.313  3.450  3.411
# 11  1.870  1.673  1.494  1.792  1.536  1.536  1.434
# 12  2.658  2.325  1.938  2.300  2.114  2.818  2.818
# 13  2.895  2.868  2.479  2.392  2.676  2.186  2.834
# 14  2.997  2.844  2.926  3.063  2.588  2.951  2.845

# %%
def calculate_stats(df):
    # Calculate mean and standard deviation for each column
    mean_values = df.mean()
    std_values = df.std()

    # Create a DataFrame to store the results
    stats_df = pd.DataFrame({'variable': ['mean', 'sd']})

    # Add mean and standard deviation values for each column
    for col in df.columns:
        stats_df[col] = [mean_values[col], std_values[col]]

    return stats_df

# %%
google_nist_stats = calculate_stats(google_nist)

# %%
chatgpt_nist_stats = calculate_stats(chatgpt_nist)

# %%
ibm_nist_stats = calculate_stats(ibm_nist)

# %%
google_nist_stats
# Out:
#   variable        hi        id        ja        ko       es        th  \
# 0     mean  2.962800  2.925467  2.853400  2.671200  2.73060  2.783800
# 1       sd  0.762348  0.790181  0.710737  0.677063  0.82549  0.816176
#
#          vi
# 0  2.844933
# 1  0.852289

# %%
# Extract mean values and standard deviations
means = google_nist_stats.loc[google_nist_stats['variable'] == 'mean'].drop(columns='variable').iloc[0]
stds = google_nist_stats.loc[google_nist_stats['variable'] == 'sd'].drop(columns='variable').iloc[0]

# Plot
plt.figure(figsize=(10, 6))
plt.bar(means.index, means, yerr=stds, capsize=5)
plt.title('Mean and SD')
plt.xlabel('Language')
plt.ylabel('BLEU score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Set up bootstrapping functions

# %%
# Bootstrap replicates function
def bootstrap_replicate_1d(data, func):
    """Generate bootstrap replicate of 1D data."""
    bs_sample = np.random.choice(data, len(data))
    return func(bs_sample)

def draw_bs_reps(data, func, size=1):
    """Draw bootstrap replicates."""
    # Initialize array of replicates: bs_replicates
    bs_replicates = np.empty(size)

    # Generate replicates
    for i in range(size):
        bs_replicates[i] = bootstrap_replicate_1d(data, func)

    return bs_replicates

# %%
def calculate_mean(df):
    # Calculate mean for each column
    mean_values = df.mean()
    # Create a DataFrame to store the results
    mean_df = pd.DataFrame({'variable': ['mean']})
    # Add mean and standard deviation values for each column
    for col in df.columns:
        mean_df[col] = [mean_values[col]]
    return mean_df

# %% [markdown]
# ## Google Translate vs. IBM

# %% [markdown]
# ### Bootstrapping

# %%
google_means = google_nist_stats.iloc[0,1:]
ibm_means = ibm_nist_stats.iloc[0,1:]
# Difference in means of Google vs. IBM
diff_means_ggl_ibm = google_means - ibm_means

# Calculate mean of all NIST scores of the two systems
mean_ggl_ibm = (google_means + ibm_means) / 2

# Create shifted data sets: original_data - data_mean + pair_mean
google_ibm_shifted = google_nist - google_means + mean_ggl_ibm
ibm_google_shifted = ibm_nist - ibm_means + mean_ggl_ibm

# Generate bootstrap replicates
bootstrap_size = 5000
 # Google bootstrap
google_ibm_bs = []

for col in google_ibm_shifted.columns:
  bs_reps = draw_bs_reps(google_ibm_shifted[col], np.mean, size = bootstrap_size)
  google_ibm_bs.append(bs_reps)
 # Combine all Series into a DataFrame
google_ibm_bs = pd.DataFrame(google_ibm_bs).transpose()
google_ibm_bs.columns = google_ibm_shifted.columns #rename columns

 # IBM bootstrap
ibm_google_bs = []

for col in ibm_google_shifted.columns:
  bs_reps = draw_bs_reps(ibm_google_shifted[col], np.mean, size = bootstrap_size)
  ibm_google_bs.append(bs_reps)
 # Combine all Series into a DataFrame
ibm_google_bs = pd.DataFrame(ibm_google_bs).transpose()
ibm_google_bs.columns = ibm_google_shifted.columns #rename columns

# %% [markdown]
# ### Print Result

# %%
# Calculate diference in means of the bootstrap replicates
bs_rep_ggl_ibm = google_ibm_bs - ibm_google_bs

# Compute p-Value
p_ggl_higher_ibm = np.sum(bs_rep_ggl_ibm > diff_means_ggl_ibm) / len(bs_rep_ggl_ibm)
p_ggl_lower_ibm = np.sum(bs_rep_ggl_ibm < diff_means_ggl_ibm) / len(bs_rep_ggl_ibm)

#Construct evaluation result
bs_rep_ggl_ibm_mean = calculate_mean(bs_rep_ggl_ibm)
bs_rep_ggl_ibm_mean.insert(0, 'h0', 'google - ibm', True)

p_ggl_higher_ibm = pd.DataFrame(p_ggl_higher_ibm).transpose() #rename(index = {0:'p-value'})
p_ggl_higher_ibm.insert(0, 'h0', 'google > ibm', True)
p_ggl_higher_ibm.insert(1, 'variable', 'p-higher', True)

p_ggl_lower_ibm = pd.DataFrame(p_ggl_lower_ibm).transpose()
p_ggl_lower_ibm.insert(0, 'h0', 'google < ibm', True)
p_ggl_lower_ibm.insert(1, 'variable', 'p-lower', True)

pd.concat([bs_rep_ggl_ibm_mean, p_ggl_higher_ibm, p_ggl_lower_ibm], ignore_index = True)
# Out:
#              h0  variable        hi        id        ja        ko        es  \
# 0  google - ibm      mean  0.004383 -0.001037 -0.001326  0.004815  0.002014
# 1  google > ibm  p-higher  0.033600  0.171600  0.005400  0.025000  0.468600
# 2  google < ibm   p-lower  0.966400  0.828400  0.994600  0.975000  0.531400
#
#          th        vi
# 0 -0.002964 -0.003333
# 1  0.058400  0.222600
# 2  0.941600  0.777400

# %% [markdown]
# Google vs. IBM:
# - Not really different from each other: hi, ko
# - Google is better than IBM: es
# - IBM is better: id, ja, th, vi

# %% [markdown]
# ## IBM vs. ChatGPT

# %% [markdown]
# ### Bootstrapping

# %%
chatgpt_means = chatgpt_nist_stats.iloc[0,1:]
ibm_means = ibm_nist_stats.iloc[0,1:]
# Difference in means of IBM vs. ChatGPT
diff_means_ibm_chatgpt = ibm_means - chatgpt_means

# Calculate mean of all NIST scores of the two systems
mean_ibm_chatgpt = (chatgpt_means + ibm_means) / 2

# Create shifted data sets: original_data - data_mean + pair_mean
chatgpt_ibm_shifted = chatgpt_nist - chatgpt_means + mean_ibm_chatgpt
ibm_chatgpt_shifted = ibm_nist - ibm_means + mean_ibm_chatgpt

# Generate bootstrap replicates
bootstrap_size = 5000
 # ChatGPT bootstrap
chatgpt_ibm_bs = []

for col in chatgpt_ibm_shifted.columns:
  bs_reps = draw_bs_reps(chatgpt_ibm_shifted[col], np.mean, size = bootstrap_size)
  chatgpt_ibm_bs.append(bs_reps)
 # Combine all Series into a DataFrame
chatgpt_ibm_bs = pd.DataFrame(chatgpt_ibm_bs).transpose()
chatgpt_ibm_bs.columns = chatgpt_ibm_shifted.columns #rename columns

 # IBM bootstrap
ibm_chatgpt_bs = []

for col in ibm_chatgpt_shifted.columns:
  bs_reps = draw_bs_reps(ibm_chatgpt_shifted[col], np.mean, size = bootstrap_size)
  ibm_chatgpt_bs.append(bs_reps)
 # Combine all Series into a DataFrame
ibm_chatgpt_bs = pd.DataFrame(ibm_chatgpt_bs).transpose()
ibm_chatgpt_bs.columns = ibm_chatgpt_shifted.columns #rename columns

# %% [markdown]
# ### Print Result

# %%
# Calculate diference in means of the bootstrap replicates
bs_rep_ibm_chatgpt = ibm_chatgpt_bs - chatgpt_ibm_bs

# Compute p-Value
p_ibm_higher_chatgpt = np.sum(bs_rep_ibm_chatgpt > diff_means_ibm_chatgpt) / len(bs_rep_ibm_chatgpt)
p_ibm_lower_chatgpt = np.sum(bs_rep_ibm_chatgpt < diff_means_ibm_chatgpt) / len(bs_rep_ibm_chatgpt)

#Construct evaluation result
bs_rep_ibm_chatgpt_mean = calculate_mean(bs_rep_ibm_chatgpt)
bs_rep_ibm_chatgpt_mean.insert(0, 'h0', 'ibm-chatgpt', True)

p_ibm_higher_chatgpt = pd.DataFrame(p_ibm_higher_chatgpt).transpose()
p_ibm_higher_chatgpt.insert(0, 'h0', 'ibm > chatgpt', True)
p_ibm_higher_chatgpt.insert(1, 'variable', 'p-higher', True)

p_ibm_lower_chatgpt = pd.DataFrame(p_ibm_lower_chatgpt).transpose()
p_ibm_lower_chatgpt.insert(0, 'h0', 'ibm < chatgpt', True)
p_ibm_lower_chatgpt.insert(1, 'variable', 'p-lower', True)

pd.concat([bs_rep_ibm_chatgpt_mean, p_ibm_higher_chatgpt, p_ibm_lower_chatgpt], ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-dbe2997c6d12> in <cell line: 2>()
#       1 # Calculate diference in means of the bootstrap replicates
# ----> 2 bs_rep_ibm_chatgpt = ibm_chatgpt_bs - chatgpt_ibm_bs
#       3
#       4 # Compute p-Value
#       5 p_ibm_higher_chatgpt = np.sum(bs_rep_ibm_chatgpt > diff_means_ibm_chatgpt) / len(bs_rep_ibm_chatgpt)
#
# NameError: name 'ibm_chatgpt_bs' is not defined

# %% [markdown]
# ## ChatGPT vs. Google Translate

# %% [markdown]
# ### Bootstrapping

# %%
chatgpt_means = chatgpt_nist_stats.iloc[0,1:]
google_means = google_nist_stats.iloc[0,1:]
# Difference in means of ChatGPT vs. Google Translate
diff_means_chatgpt_google = chatgpt_means - google_means

# Calculate mean of all NIST scores of the two systems
mean_chatgpt_google = (chatgpt_means + google_means) / 2

# Create shifted data sets: original_data - data_mean + pair_mean
chatgpt_ggl_shifted = chatgpt_nist - chatgpt_means + mean_chatgpt_google
ggl_chatgpt_shifted = google_nist - google_means + mean_chatgpt_google

# Generate bootstrap replicates
bootstrap_size = 5000
 # ChatGPT bootstrap
chatgpt_google_bs = []

for col in chatgpt_ggl_shifted.columns:
  bs_reps = draw_bs_reps(chatgpt_ggl_shifted[col], np.mean, size = bootstrap_size)
  chatgpt_google_bs.append(bs_reps)
 # Combine all Series into a DataFrame
chatgpt_google_bs = pd.DataFrame(chatgpt_ggl_shifted).transpose()
chatgpt_google_bs.columns = chatgpt_ggl_shifted.columns #rename columns

 # Google bootstrap
google_chatgpt_bs = []

for col in ggl_chatgpt_shifted.columns:
  bs_reps = draw_bs_reps(ggl_chatgpt_shifted[col], np.mean, size = bootstrap_size)
  google_chatgpt_bs.append(bs_reps)
 # Combine all Series into a DataFrame
google_chatgpt_bs = pd.DataFrame(google_chatgpt_bs).transpose()
google_chatgpt_bs.columns = ggl_chatgpt_shifted.columns #rename columns

# %% [markdown]
# ### Print Result

# %%
# Calculate diference in means of the bootstrap replicates
bs_rep_chatgpt_google = chatgpt_google_bs - google_chatgpt_bs

# Compute p-Value
p_chatgpt_higher_google = np.sum(bs_rep_chatgpt_google > diff_means_chatgpt_google) / len(bs_rep_chatgpt_google)
p_chatgpt_lower_google = np.sum(bs_rep_chatgpt_google < diff_means_chatgpt_google) / len(bs_rep_chatgpt_google)

# Construct evaluation result
bs_rep_chatgpt_google_mean = calculate_mean(bs_rep_chatgpt_google)
bs_rep_chatgpt_google_mean.insert(0, 'h0', 'chatgpt - google', True)

p_chatgpt_higher_google = pd.DataFrame(p_chatgpt_higher_google).transpose()
p_chatgpt_higher_google.insert(0, 'h0', 'chatgpt > google', True)
p_chatgpt_higher_google.insert(1, 'variable', 'p-higher', True)

p_chatgpt_lower_google = pd.DataFrame(p_chatgpt_lower_google).transpose()
p_chatgpt_lower_google.insert(0, 'h0', 'chatgpt < google', True)
p_chatgpt_lower_google.insert(1, 'variable', 'p-lower', True)

pd.concat([bs_rep_chatgpt_google, p_chatgpt_higher_google, p_chatgpt_lower_google], ignore_index = True)

# %% [markdown]
# ## Put them all together

# %%
pd.concat([bs_rep_ggl_ibm_mean, p_ggl_higher_ibm, p_ggl_lower_ibm,
           bs_rep_ibm_chatgpt_mean, p_ibm_higher_chatgpt, p_ibm_lower_chatgpt,
           bs_rep_chatgpt_google, p_chatgpt_higher_google, p_chatgpt_lower_google], ignore_index = True)
