# %% [markdown]
# <a href="https://colab.research.google.com/github/rnagamatsu/textanalytics_group2/blob/main/Copy_of_main_code_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
# !pip install ibm_watson
# !pip install openai
# !pip install google.cloud
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Collecting ibm_watson
#   Downloading ibm-watson-8.0.0.tar.gz (398 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.3/398.3 kB 2.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (2.8.2)
# Requirement already satisfied: websocket-client>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (1.8.0)
# Collecting ibm-cloud-sdk-core==3.*,>=3.3.6 (from ibm_watson)
#   Downloading ibm-cloud-sdk-core-3.20.0.tar.gz (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting urllib3<3.0.0,>=2.1.0 (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson)
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 12.1 MB/s eta 0:00:00
# Collecting PyJWT<3.0.0,>=2.8.0 (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson)
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.5.3->ibm_watson) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (2024.2.2)
# Building wheels for collected packages: ibm_watson, ibm-cloud-sdk-core
#   Building wheel for ibm_watson (pyproject.toml) ... done
#   Created wheel for ibm_watson: filename=ibm_watson-8.0.0-py3-none-any.whl size=401037 sha256=a50afbc6dfc16a0ba13462de4fb18e98d9d4be507d1471e1d605ac34778ff95c
#   Stored in directory: /root/.cache/pip/wheels/3b/7f/40/3601b4f434eb462a9f46e24b9dd8c96881e6e913a18cc904f9
#   Building wheel for ibm-cloud-sdk-core (pyproject.toml) ... done
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-3.20.0-py3-none-any.whl size=101424 sha256=78ff6a2d53c285686f6d20215a49ea56b94ecf77963c64160beece082560fb7d
#   Stored in directory: /root/.cache/pip/wheels/d0/1c/35/8ae2b2b46ca9f86d9edcc026eb0f1a5e8237b712ea3e1ba6c4
# Successfully built ibm_watson ibm-cloud-sdk-core
# Installing collected packages: urllib3, PyJWT, ibm-cloud-sdk-core, ibm_watson
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# Successfully installed PyJWT-2.8.0 ibm-cloud-sdk-core-3.20.0 ibm_watson-8.0.0 urllib3-2.2.1
# Collecting openai
#   Downloading openai-1.27.0-py3-none-any.whl (314 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.1/314.1 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.1 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.27.0
# Collecting google.cloud
#   Downloading google_cloud-0.34.0-py2.py3-none-any.whl (1.8 kB)
# Installing collected packages: google.cloud
# Successfully installed google.cloud-0.34.0

# %%
import requests
import pandas as pd
import numpy as np
import os
import nltk
import matplotlib.pyplot as plt
from google.cloud import translate_v2 as translate
from openai import OpenAI
from nltk.tokenize import word_tokenize
from nltk.translate.nist_score import sentence_nist
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %% [markdown]
# # Import Data

# %%
def get_urls(owner, repo, path):
    # Construct the URL for the GitHub API
    api_url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}"

    # Fetch the content of the GitHub repository
    response = requests.get(api_url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the response to extract file names, file objects, and file URLs
        names = [file['name'] for file in response.json()]
        urls = [f"https://raw.githubusercontent.com/{owner}/{repo}/main/{path}/{name}" for name in names]  # URLs to each file

        # Print the list of files and their corresponding URLs
        print("Files in the GitHub repository folder:")
        for name, url in zip(names, urls):
            print(f"{name}: {url}")

        return names, urls
    else:
        # If the request was not successful, print an error message
        print(f"Error: Failed to fetch content from GitHub repository. Status code: {response.status_code}")
        return [], []

# %%
# GitHub repository information
owner = "rnagamatsu"
repo = "textanalytics_group2"
path = "flores200_group2"

# Get the list of files in the GitHub repository folder
files_names, files_urls = get_urls(owner, repo, path)
# Out:
# Files in the GitHub repository folder:
# eng_Latn.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/eng_Latn.dev
# hin_Deva.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/hin_Deva.dev
# ind_Latn.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/ind_Latn.dev
# jpn_Jpan.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/jpn_Jpan.dev
# kor_Hang.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/kor_Hang.dev
# spa_Latn.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/spa_Latn.dev
# tha_Thai.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/tha_Thai.dev
# vie_Latn.dev: https://raw.githubusercontent.com/rnagamatsu/textanalytics_group2/main/flores200_group2/vie_Latn.dev

# %%
def process_flores(files_names, files_urls):
    dfs = []

    for index, (name, url) in enumerate(zip(files_names, files_urls)):
        response = requests.get(url)
        if response.status_code == 200:
            print(f"Downloaded and processed file {index+1}/{len(files_names)}: {name}")
            text = response.text
            df_name = name[:3]
            df = pd.DataFrame(text.split('\n'), columns=[df_name])
            dfs.append(df)
        else:
            print(f"Error: Failed to download file {name}")

    # Concatenate the DataFrames along the columns axis
    if dfs:
        concatenated_df = pd.concat(dfs, axis=1)
        # Last row is empty
        concatenated_df.drop(concatenated_df.index[-1], inplace=True)
        return concatenated_df
    else:
        print("No DataFrames to concatenate.")
        return None

# %%
references = process_flores(files_names, files_urls)
# Out:
# Downloaded and processed file 1/8: eng_Latn.dev
# Downloaded and processed file 2/8: hin_Deva.dev
# Downloaded and processed file 3/8: ind_Latn.dev
# Downloaded and processed file 4/8: jpn_Jpan.dev
# Downloaded and processed file 5/8: kor_Hang.dev
# Downloaded and processed file 6/8: spa_Latn.dev
# Downloaded and processed file 7/8: tha_Thai.dev
# Downloaded and processed file 8/8: vie_Latn.dev

# %%
# Rename columns to universal language code
references.columns = ['en', 'hi', 'id', 'ja', 'ko', 'es', 'th', 'vi']

# %%
# Reduce the size of the data for the analysis
references = references[:50]

# %%
references
# Out:
#                                                    en  \
# 0   On Monday, scientists from the Stanford Univer...
# 1   Lead researchers say this may bring early dete...
# 2   The JAS 39C Gripen crashed onto a runway at ar...
# 3   The pilot was identified as Squadron Leader Di...
# 4   Local media reports an airport fire vehicle ro...
# 5   28-year-old Vidal had joined Barça three seaso...
# 6   Since moving to the Catalan-capital, Vidal had...
# 7   The protest started around 11:00 local time (U...
# 8   Just after 11:00, protesters blocked traffic o...
# 9   At 11:20, the police asked the protesters to m...
# 10  Around 11:29, the protest moved up Whitehall, ...
# 11  Nadal's head to head record against the Canadi...
# 12  He recently lost against Raonic in the Brisban...
# 13  Nadal bagged 88% net points in the match winni...
# 14  After the match, King of Clay said, "I am just...
# 15  "Panama Papers" is an umbrella term for roughl...
# 16  The documents showed fourteen banks helped wea...
# 17  British newspaper The Guardian suggested Deuts...
# 18  There were protests worldwide, several crimina...
# 19  Born in Hong Kong, Ma studied at New York Univ...
# 20  Hsieh implied during the election that Ma migh...
# 21  Hsieh also argued that the photogenic Ma was m...
# 22  Despite these accusations, Ma won handily on a...
# 23  Today's Player of the Day is Alex Ovechkin of ...
# 24  He had 2 goals and 2 assists in Washington's 5...
# 25  Ovechkin's first assist of the night was on th...
# 26  his second goal of the night was his 60th of t...
# 27  Batten was ranked 190th on the 2008 400 Riches...
# 28  He graduated from the College of Arts & Scienc...
# 29  Iraq's Abu Ghraib prison has been set alight d...
# 30  The jail became notorious after prisoner abuse...
# 31  Piquet Jr. crashed in the 2008 Singapore Grand...
# 32  As the cars ahead of Alonso went in for fuel u...
# 33  Piquet Jr. was sacked after the 2009 Hungarian...
# 34  At exactly 8:46 a.m. a hush fell across the ci...
# 35  Two beams of light have been rigged up to poin...
# 36  Construction is ongoing for five new skyscrape...
# 37  The PBS show has more than two-dozen Emmy awar...
# 38  Each episode of the show would focus on a them...
# 39  Each show would also provide recommendations f...
# 40  John Grant, from WNED Buffalo (Reading Rainbow...
# 41  It is believed by some, including John Grant, ...
# 42  The storm, situated about 645 miles (1040 km) ...
# 43  Fred currently has winds of 105 miles per hour...
# 44  Fred is the strongest tropical cyclone ever re...
# 45  On September 24, 1759, Arthur Guinness signed ...
# 46  250 years later, Guinness has grown to a globa...
# 47  Jonny Reid, co-driver for the A1GP New Zealand...
# 48  Mr Reid managed to drive the New Zealand's A1G...
# 49  The New Zealand police had trouble using their...
#
#                                                    hi  \
# 0   सोमवार को, स्टैनफ़ोर्ड यूनिवर्सिटी स्कूल ऑफ़ म...
# 1   शोधकर्ताओं ने कहा है कि यह अल्प आय वाले देशों ...
# 2   स्थानीय समय (0230 UTC) के मुताबिक करीब 9:30 बज...
# 3   पायलट की पहचान स्क्वाड्रन लीडर दिलोकृत पटावी क...
# 4   स्थानीय मीडिया ने बताया है कि कार्रवाई करने के...
# 5   28 वर्षीय विडाल तीन सीजन पहले सेविला से बारका ...
# 6   कातलान की राजधानी (बार्सिलोना) में जाने के बाद...
# 7   व्हाइटहॉल पर लगभग 11:00 बजे स्थानीय समय (यूटीस...
# 8   ठीक 11:00 बजे के बाद, व्हाइटहॉल में उत्तर की ओ...
# 9   11:20 पर, पुलिस ने प्रदर्शनकारियों को यह कहते ...
# 10  11:29 बजे के आस-पास, विरोध करने वाले लोग व्हाइ...
# 11      कनाडियन के खिलाफ नडाल का सीधा रिकॉर्ड 7-2 है।
# 12  वे हाल ही में ब्रिस्बेन ओपन में रोनिक के खिलाफ...
# 13  फ़र्स्ट सर्व में नडाल को 76 मैच विनिंग पॉइंट्स...
# 14  मैच के बाद, क्ले के राजा ने कहा, “मैं सबसे महत...
# 15  “पनामा पेपर्स” पनामा की कानूनी फर्म मोसाक फोंस...
# 16  दस्तावेजों से पता चलता है कि चौदह बैंकों ने अम...
# 17  ब्रिटिश अख़बार द गार्जियन के अनुसार ड्यूश बैंक...
# 18  दुनिया भर में विरोध प्रदर्शन हुए, कई आपराधिक म...
# 19  मा का जन्म हांगकांग में हुआ था, उन्होंने न्यूय...
# 20  चुनाव के दौरान साइह ने जताया कि संकट के दौर मे...
# 21  शय ने यह भी तर्क दिया कि फ़ोटोजेनिक मा हक़ीक़त...
# 22  इन आरोपों के बावजूद, मा ने चीनी महाद्वीप के सा...
# 23  आज के खिलाड़ी वॉशिगंटन कैपिटल्स के एलेक्स ओवेच...
# 24  अटलांटा थ्रैशर्स पर वाशिंगटन की 5-3 की जीत में...
# 25  उस रात रूकी निकल्स बैकस्ट्रॉम के खेल जिताने वा...
# 26  रात का उनका दूसरा गोल सीज़न का उनका 60वाँ गोल ...
# 27  2008 के 400 सबसे अमीर अमेरिकियों की सूची में ब...
# 28  उन्होंने 1950 में वर्जीनिया यूनिवर्सिटी के कला...
# 29  इराक की अबू ग़रीब जेल को दंगे के दौरान आग के ह...
# 30  कैदी दुर्व्यवहार के पता चलने का बाद जेल कुख्या...
# 31  फ़र्नांडो अलोंसो के लिए एक शुरुआती पिट स्टॉप के...
# 32  जैसे ही अलोंसो के आगे की कारें सेफ्टी कार के न...
# 33  पिकेट जूनियर को 2009 हंगरी ग्रैंड प्री के बाद ...
# 34  ठीक 8:46 बजे, सुबह पूरे शहर मे चुप्पी फैल गई, ...
# 35  रातभर आसमान की ओर देखने के लिए प्रकाश की दो कि...
# 36  साईट पर पांच नई गगनचुम्बी इमारतों पर काम चल रह...
# 37  इस PBS शो को दो दर्जन से ज़्यादा एमी पुरस्कार म...
# 38  शो का हर एक एपिसोड एक ख़ास पुस्तक की थीम पर के...
# 39  हर शो में कुछ किताबों के बारे में सलाह भी दी ज...
# 40  डब्ल्यूएनईडी बफेलो से (Rainbow's home station ...
# 41  जॉन ग्रांट सहित कुछ लोगों का मानना है कि फंडिं...
# 42  पूर्वानुमान कहते हैं कि यह तूफ़ान केप वर्डे द्...
# 43  इस समय फ़्रेड 105 मील प्रति घंटे (165 किमी प्र...
# 44  सैटेलाइट इमेजरी के आगमन के बाद से फ़्रेड अटलां...
# 45  24 सितंबर, 1759 को, आर्थर गिनीज़ ने डबलिन, आयर...
# 46  250 साल बाद, गिनीज़ एक वैश्विक व्यवसाय बन चुका...
# 47  आज A1GP न्यूज़ीलैंड टीम के को-ड्राइवर जॉनी रेड...
# 48  श्री रीड न्यूज़ीलैंड की A1GP कार, ब्लैक ब्यूटी ...
# 49  ब्लैक ब्यूटी के छोटे आकार की वजह से न्यूज़ीलैंड...
#
#                                                    id  \
# 0   Ilmuwan dari Stanford University School of Med...
# 1   Ketua peneliti mengatakan bahwa diagnosis ini ...
# 2   JAS 39C Gripen jatuh ke landasan pacu sekitar ...
# 3   Pilot tersebut diidentifikasi sebagai Pemimpin...
# 4   Media lokal melaporkan sebuah kendaraan pemada...
# 5   Vidal yang berusia 28 tahun bergabung dengan B...
# 6   Sejak menetap di ibu kota Catalan, Vidal sudah...
# 7   Protes dimulai sekitar pukul 11.00 waktu setem...
# 8   Pengunjuk rasa tepat setelah pukul 11.00 membl...
# 9   Pada pukul 11.20, polisi meminta para pengunju...
# 10  Sekitar pukul 11.29, para pengunjuk rasa berpi...
# 11  Adu rekor Nadal melawan petenis asal Kanada te...
# 12  Baru-baru ini dia kalah melawan Raonic di Bris...
# 13  Nadal mengantongi 88% poin bersih dalam laga i...
# 14  "Seusai pertandingan, Raja Tanah Liat berkata,...
# 15  "Panama Papers" adalah istilah umum untuk seki...
# 16  Dokumen tersebut memperlihatkan empat belas ba...
# 17  Surat kabar Inggris The Guardian menyebutkan b...
# 18  Ada protes di seluruh dunia, beberapa tuntutan...
# 19  "Lahir di Hong Kong, Ma belajar di Universitas...
# 20  Hsieh menyiratkan selama pemilu Ma mungkin saj...
# 21  Hsieh juga membantah bahwa Ma yang fotogenik l...
# 22  Sekalipun mendapat tuduhan-tuduhan ini, Ma men...
# 23  Pemain Terbaik Hari Ini ialah Alex Ovechkin da...
# 24  Dia menghasilkan 2 gol dan 2 assist dalam keme...
# 25  Asis pertama Ovechkin malam itu ada pada gol k...
# 26  Gol keduanya malam itu adalah yang ke-60 musim...
# 27  Batten menduduki peringkat ke-190 pada daftar ...
# 28  Dia lulus dari Sekolah Tinggi Seni dan Sains U...
# 29  Penjara Abu Ghraib Irak dibakar saat terjadi k...
# 30  Penjara menjadi terkenal setelah ditemukan ada...
# 31  Piquet Jr. mengalami kecelakaan di Grand Prix ...
# 32  Saat mobil di depan Alonso mengisi bahan bakar...
# 33  Piquet Jr. dipecat setelah Grand Prix Hongaria...
# 34  Tepat pukul 08.46 pagi, seluruh kota hening, m...
# 35  Dua berkas cahaya disorotkan ke arah langit se...
# 36  Pembangunan lima gedung pencakar langit baru s...
# 37  Acara TV PBS ini meraih lebih dari dua puluh p...
# 38  Setiap episode acara tersebut fokus pada tema ...
# 39  Setiap acara akan memberi rekomendasi buku yan...
# 40  "John Grant, dari WNED Buffalo (stasiun induk ...
# 41  John Grant dan beberapa orang percaya bahwa kr...
# 42  Menurut peramal cuaca, badai yang berada di se...
# 43  Fred saat ini memiliki kecepatan angin 105 mil...
# 44  Fred adalah badai tropis terkuat yang terekam ...
# 45  Arthur Guinness meneken perjanjian sewa 9.000 ...
# 46  250 tahun kemudian, Guinness berkembang menjad...
# 47  Jonny Reid, pendamping pengemudi untuk tim A1G...
# 48  Tuan Reid berhasil mengemudikan mobil A1 GP mi...
# 49  Polisi Selandia Baru kesulitan memakai radar p...
#
#                                                    ja  \
# 0   月曜日にスタンフォード大学医学部の科学者たちは、細胞を種類別に分類できる新しい診断ツールを発...
# 1   主任研究者は、これは低所得国における患者の癌、結核、HIV、マラリアの早期発見につながる可能...
# 2   JAS 39Cグリペンは現地時間の午前9時30分頃（UTC 0230）に滑走路に墜落して爆発...
# 3                操縦士は中隊長のディロクリット・パタヴェー氏であることが確認されました。
# 4               地元メディアの報道によると、空港の消防車が対応中に横転したということです。
# 5          28歳のビダル選手は、3シーズン前にセビージャから移籍してバルサに所属していました。
# 6                カタルーニャの州都に移って以来、ビダルはクラブで49試合に出場しました。
# 7   抗議行動は、現地時間11:00（UTC+1）頃にホワイトホール通りで始まり、首相官邸があるダ...
# 8            11時すぎちょうどに抗議者たちはホワイトホールの北行き車両の交通を遮断しました。
# 9   11時20分になると、警察は抗議する権利と交通量のバランスを弁える必要があると告げて、抗議者...
# 10  11時29分頃、デモ隊は英国政府に向かい、トラファルガー広場を通り過ぎて、ストランド街沿いに...
# 11                                ナダルの対カナダ戦の戦績は7-2です。
# 12                      最近では、ブリスベン・オープンでラオニッチに敗れています。
# 13    試合中にナダルはファーストサーブで76ポイントを奪い、88%のネットポイントを獲得しています。
# 14  試合後にキング・オブ・クレーは、「最も重要なイベントの決勝に戻ってきたことに興奮している。こ...
# 15  「パナマ文書とは」、2016年春にパナマの法律事務所モサック・フォンセカから報道機関に流出し...
# 16  文書には、富裕層の顧客が税金等の規制を逃れて数十億ドルの資産を隠す際に14の銀行が手助けした...
# 17  英国のガーディアン紙は、ドイツ銀行が1200社のペーパーカンパニーの約3分の1を支配している...
# 18  世界中で抗議の声が上がり、何件もの刑事告発があり、アイスランドとパキスタンの両政府の指導者が...
# 19  香港生まれの馬英九は、ニューヨーク大学とハーバード大学法学大学院を卒業し、米国の永住権「グリ...
# 20           選挙中に謝氏は、危機に陥ったら馬氏は逃げ出すかもしれないとほのめかしていました。
# 21                 謝長廷は、馬英九について実物よりも写真写りが良いと主張していました。
# 22            こうした非難にもかかわらず、馬氏は中国大陸との緊密な関係を標榜して楽勝でした。
# 23  今日のプレイヤー・オブ・ザ・デイは、ワシントン・キャピトルズのアレックス・オヴェーチキン選手です。
# 24  ワシントンがアトランタ・トラッシャーズに5-3で勝利した際には2ゴール2アシストを記録しています。
# 25  この夜、オベーチキンの最初のアシストは、ルーキーのニックラス・バックストロームが決めた決勝ゴ...
# 26  その夜の2つ目のゴールは、彼の今季60点目のゴールとなりました。1シーズンで60点以上を記録...
# 27       バッテン氏は2008年版アメリカ長者番付で190位に入り、推定資産額は23億ドルでした。
# 28          彼は、1950年にバージニア大学芸術科学部を卒業し、同大学に多額の寄付をしました。
# 29                      イラクのアブ・グライブ刑務所が暴動の最中に放火されました。
# 30               米軍による占領後、囚人の虐待が発覚し、当該刑務所の悪名がとどろきました。
# 31  ピケJr.は2008年のシンガポールGPで、フェルナンド・アロンソが早めにピットインした直後...
# 32  先行するマシンがセーフティカーの後ろで燃料を補給する中、アロンソは集団の中で順位を上げて勝利...
# 33                      ピケJr.は2009年のハンガリーGP後に解雇されました。
# 34    午前8時46分ちょうどに街中が静寂に包まれました。最初のジェット機が目標に衝突した瞬間でした。
# 35                          二筋の光が一晩中空に向かうように配備されています。
# 36      敷地内には新たに5つの超高層ビルが建設中で、その中央には交通センターと記念公園があります。
# 37  このPBSの番組はエミー賞を20回以上も受賞しており、この番組よりも長寿の番組は「セサミスト...
# 38  この番組のエピソードはいずれも具体的な書籍のテーマに焦点を当て、いくつもの物語を通してそのテ...
# 39  また、それぞれの番組では子どもたちが図書館に行ったときに探すべきお勧めの本に関する情報も提供...
# 40  WNED Buffalo（リーディングレインボーの放送局）のジョン・グラント氏は、「リーディ...
# 41  ジョン・グラントほか一部の人たちは、資金不足と教育テレビ番組に関する考え方の変化がシリーズ終...
# 42  暴風雨は、カーボベルデ諸島の西約645マイル(1040 km)の位置まで来ているが、上陸する...
# 43        フレッドは現在、時速105マイル（165km/h）の風速で北西に向かって進んでいます。
# 44  フレッドは、衛星画像が導入されて以来、大西洋のはるか南と東で記録された最大の熱帯低気圧であり...
# 45  ギネスビール創業者のアーサー・ギネスは、1759年9月24日にアイルランドのダブリンにあるセ...
# 46  その250年後にギネスは年間売上100億ユーロ（147億米ドル）を上回る世界的なビジネスへの...
# 47  A1GPニュージーランドチームのコ・ドライバーであるジョニー・リードは本日、48年以上の歴史...
# 48  リード氏は、ニュージーランドのA1GPカーである「ブラックビューティー」で時速160 km以...
# 49  ニュージーランドの警察は、ブラックビューティーの速度が低いため、速度計測器でリード氏の速度を...
#
#                                                    ko  \
# 0   스탠포드 의과대학 연구진은 지난 월요일 세포를 유형별로 분류할 수 있는 새로운 진단...
# 1   수석 연구진들은 이것이 선진국 대비 절반의 생존율을 보이는 저소득 국가들의 환자들에...
# 2   현지 시간으로 약 아침 9시 30분(0230 UTC)에 JAS 39C 그리펜이 활주...
# 3                     그 조종사는 비행 중대장 딜로크리트 패타비로 확인되었다.
# 4          현지 언론은 공항 소방차가 사고에 대응하는 도중에 전복되었다고 보도했습니다.
# 5            28세인 비달은 3년 전 세비야 FC에서 FC 바르셀로나에 합류했습니다.
# 6                바르셀로나로 이적한 후 비달은 클럽을 위해 49경기를 뛰었습니다.
# 7   시위는 총리의 공식 거주지인 다우닝가의 경찰이 경비를 서는 입구 맞은편 화이트홀에서...
# 8   11시가 막 지난 후, 시위대는 화이트홀에 있는 북쪽으로 향하는 마차들의 교통을 막았다.
# 9   11시 20분에 경찰이 시위대에게 보도로 돌아가도록 요청했으며, 시위할 권리와 증가...
# 10  11시 29분 경, 시위대는 스트랜드를 따라 트라팔가 광장을 지나 화이트 홀로 입성...
# 11                 나달과 이 캐나다 선수와의 정면 대결 기록은 7 대 2입니다.
# 12  그는 최근 브리즈번 오픈(Brisbane Open) 경기에서 라오니치(Raonic)...
# 13          나달은 첫 서브에서 76점을 획득하며 88%의 네트 포인트를 달성했습니다.
# 14  경기가 끝난 후 클레이의 왕은 “가장 중요한 종목의 마지막 라운드에 복귀한 것만으로...
# 15  """파나마 페이퍼스(Panama Papers)""는 2016년 봄, 언론에 유출된...
# 16  문서에 따르면 14개의 은행이 부유한 고객을 도와 세금 및 기타 규제를 피할 수 있...
# 17  영국 신문 가디언지는 도이치 뱅크는 이것을 이루기 위해 사용된 대략 1200개의 비...
# 18  전 세계적으로 시위가 있었고, 여러 건의 형사 고발이 있었으며, 파키스탄 정부와 아...
# 19  마(Ma) 씨는 홍콩에서 태어나 뉴욕대와 하버드대 로스쿨에서 공부했으며 미국 영주권...
# 20  셰이(Hsieh)는 선거 기간 동안 마(Ma)가 위기의 시기에 망명할 수 있음을 암...
# 21         또한 셰이는 사진 잘 받는 마가 스타일은 멋있지만 실속은 없다고 말했습니다.
# 22  이러한 고발에도 불구하고, 마는 중국 본토와의 긴밀한 유대를 옹호하는 플랫폼을 쉽게...
# 23                     오늘의 선수는 워싱턴 캐피털즈의 알렉스 오베츠킨입니다.
# 24  Atlanta Thrashers를 상대로 5-3으로 이긴 Washington의 경기...
# 25   그날 밤 오베치킨의 첫 어시스트는 신인 니클라스 백스트롬의 경기 결승골로 이어졌습니다.
# 26  그날 밤 그의 두 번째 골은 시즌의 시즌의 60번째였으며, 1995-1996년 시즌...
# 27  배튼씨는 2008년 400명의 미국 내 부자 순위에서 약 23억 달러의 재산으로 1...
# 28  그는 1950년에 버지니아 대학에서 예술 과학을 전공으로 졸업했고 상당한 기부자로 ...
# 29          이라크의 아부 그라이브 교도소에서 폭동이 일어난 동안 화재가 발생했습니다.
# 30            미군 점령 후에 수감자 학대 사건이 밝혀지자 교도소의 악명은 높아졌다.
# 31  피케 주니어는 2008년 싱가포르 그랑프리에서 페르난도 알론소가 미리 피트스톱을 실...
# 32  알론소 앞에 있던 차들이 안전차 밑으로 연료를 넣으러 들어가자, 그는 승기를 잡기 ...
# 33       피케 주니어(Piquet Jr.)는 2009년 헝가리 그랑프리 이후 파면되었다.
# 34  정적이 도시 전체에 덮여 있는 정확히 오전 8시 46분, 그 순간 첫 번째 제트기가...
# 35             두 광선 기둥이 밤새 하늘 방향을 가리키기 위해 설치되어 있었습니다.
# 36  현장에서는 다섯 개의 고층 건물과 가운데 위치하는 교통 센터와 기념 공원이 건설 중...
# 37  그 PBS 쇼는 24번 이상의 에미상을 수상했고, 유일하게 세서미 스트리트(Sesa...
# 38  이 쇼의 각 에피소드는 특정 책의 주제에 초점을 맞춘 다음, 여러 이야기를 통해 그...
# 39        각 쇼마다 어린이들이 도서관에 가서 꼭 읽어봐야 할 책을 권장해 주기도 한다.
# 40  "WNED 버팔로(리딩 레인보우의 채널사)의 존 그랜트는 ""리딩 레인보우는 아이들...
# 41  존 그랜트(John Grant)를 포함한 일부 사람들은 자금 조달 문제 및 교육용 ...
# 42  일기예보에 따르면 카보베르데 섬 서쪽으로 약 645마일(1040 킬로미터) 지점에 ...
# 43          프레드는 현재 시속 165km의 바람을 타고 북서쪽으로 이동하고 있습니다.
# 44  프레드는 위성사진의 출현 이후 지금까지 대서양의 남쪽과 동쪽에 기록된 가장 강력한 ...
# 45  1759년 9월 24일, 아서 기네스는 아일랜드 더블린에 있는 세인트 제임스 게이트...
# 46  250년 뒤 기네스(Guinness)은 매년 100억 유로(약 147억 달러)가 넘...
# 47  A1GP 뉴질랜드 팀의 공동 드라이버인 Jonny Reid는 48년 된 뉴질랜드 오...
# 48  리드 씨는 뉴질랜드의 A1GP 차량인 블랙 뷰티를 시속 160km 이상으로 일곱 번...
# 49  뉴질랜드 경찰은 레이드 씨가 차가 낮아서 속도 측정기를 이용해 얼마나 빨리 가고 있...
#
#                                                    es  \
# 0   El lunes, los científicos de la facultad de me...
# 1   Los principales investigadores principales sos...
# 2   El JAS 39C Gripen impactó contra una pista cer...
# 3   Se identificó al piloto como Dilokrit Pattavee...
# 4   La prensa local informó que una patrulla de bo...
# 5   Vidal, de 28 años de edad y procedente del Sev...
# 6   Desde su mudanza a la capital catalana, Vidal ...
# 7   La manifestación inició cerca de las 11:00 hor...
# 8   Apenas pasadas las 11:00 h, los integrantes de...
# 9   A las 11:20, la policía solicitó a los manifes...
# 10  Cerca de las 11:29, la manifestación se abrió ...
# 11  El récord mano a mano de Nadal contra el canad...
# 12  Fue derrotado, hace poco, por Raonic en el Bri...
# 13  En el partido, Nadal acumuló un 88% de puntos ...
# 14  Después del partido, el Rey del Polvo declaró:...
# 15  La expresión genérica «Papeles de Panamá» se r...
# 16  La documentación reveló que catorce entidades ...
# 17  El periódico británico The Guardian señaló que...
# 18  Se llevaron a cabo manifestaciones a nivel mun...
# 19  Ma, oriunda de Hong Kong, se formó en la Unive...
# 20  Durante las elecciones, Hsieh insinuó que Ma p...
# 21  Hsieh también manifestó que el agraciado Ma er...
# 22  Ma logró una cómoda victoria, pese a estas acu...
# 23  Alex Ovechkin, de Washington Capitals, es el d...
# 24  Marcó 2 goles y 2 asistencias en el triunfo po...
# 25  Ovechkin hizo su primera asistencia de la noch...
# 26  Su segunda anotación de la noche fue su número...
# 27  Batten alcanzó la posición 190 dentro del list...
# 28  Obtuvo su diploma en 1950, en la Facultad de A...
# 29  La prisión de Abu Ghraib en Irak se incendió d...
# 30  La cárcel se hizo conocida después de que sali...
# 31  Durante el Gran Premio de Singapur de 2008, ju...
# 32  Cuando los automóviles delante de Alonso se de...
# 33  Luego del GP de Hungría en el año 2009, expuls...
# 34  Exactamente a las 8:46 a. m., la ciudad se vol...
# 35  Se montaron dos haces de luz direccionados al ...
# 36  En el lugar se están edificando cinco nuevos r...
# 37  El programa de PBS tiene más de veinticuatro p...
# 38  Cada episodio del programa se desarrollaría en...
# 39  En cada episodio, además, se brindaba informac...
# 40  John Grant, de WNED Buffalo (la estación más i...
# 41  Hay quienes piensan, incluido John Grant, que ...
# 42  Según los meteorólogos, hay altas probabilidad...
# 43  En la actualidad, los vientos de Fred alcanzan...
# 44  Fred es el ciclón tropical más agresivo que se...
# 45  El 24 de septiembre de 1759, Arthur Guinness s...
# 46  Un cuarto de milenio más tarde, Guinness se ha...
# 47  Jonny Reid, copiloto del equipo de Nueva Zelan...
# 48  Reid logró conducir siete veces a través del p...
# 49  Debido a lo bajo que se encuentra Black Beauty...
#
#                                                    th  \
# 0   เมื่อวันจันทร์ที่ผ่านมา นักวิทยาศาสตร์จากโรงเร...
# 1   นักวิจัยชั้นนำกล่าวว่าสิ่งนี้อาจทำให้มีการตรวจ...
# 2   JAS 39C Gripen ตกลงบนรันเวย์เมื่อเวลาประมาณ 09...
# 3   นักบินคนดังกล่าวถูกระบุว่าเป็นนาวาอากาศตรีดิลก...
# 4   ผู้สื่อข่าวท้องถิ่นรายงานว่ารถดับเพลิงประจำสนา...
# 5   วิดัลวัย 28 ปี ย้ายจากเซบีญ่ามาเข้าร่วมกับบาร์...
# 6   นับตั้งแต่ย้ายมาที่เมืองหลวงของกาตาลุญญา วิดัล...
# 7   การประท้วงเริ่มขึ้นประมาณ 11.00 น. ตามเวลาท้อง...
# 8   หลังเวลา 11.00 น. พอดิบพอดี ผู้ประท้วงปิดกั้นก...
# 9   เมื่อเวลา 11.20 น. ตำรวจได้ขอให้ผู้ประท้วงย้าย...
# 10  เมื่อประมาณ 11.29 น. การประท้วงได้เคลื่อนตัวจา...
# 11  สถิติการแข่งเฮด-ทู-เฮดของนาดาลกับผู้เล่นชาวแคน...
# 12  เขาเพิ่งพ่ายแพ้ราโอนิกเมื่อไม่นานมานี้ในบริสเบ...
# 13  นาดาลเก็บคะแนนไป 88% ถ้วนในการแข่งขัน ชนะด้วย ...
# 14  หลังจบการแข่งขัน ราชาคอร์ตดินกล่าวว่า "ผมตื่นเ...
# 15  เอกสารปานามาเป็นคำศัพท์ที่ครอบคลุมในวงกว้างที่...
# 16  เอกสารต่าง ๆ ชี้ให้เห็นว่าธนาคาร 14 แห่งได้ช่ว...
# 17  หนังสือพิมพ์เดอะการ์เดียนของอังกฤษแย้มดอยซ์แบง...
# 18  มีการประท้วงเกิดขึ้นทั่วโลก มีการฟ้องร้องทางอา...
# 19  หม่า เกิดในฮ่องกง เรียนที่มหาวิทยาลัยนิวยอร์กแ...
# 20  เซียะพูดอย่างมีนัยในระหว่างการเลือกตั้งว่าหม่า...
# 21  เซียะยังถกเถียงอีกด้วยว่าหม่าซึ่งถ่ายรูปขึ้นนั...
# 22  แม้จะมีข้อกล่าวหาเหล่านี้ แต่หม่าก็ชนะบนแพลตฟอ...
# 23  ผู้เล่นประจำวันของวันนี้คือ อเล็กซ์ โอเวคคิน จ...
# 24  เขายิงได้ 2 ประตูและส่งลูกให้คนอื่นยิงประตู 2 ...
# 25  การส่งลูกเพื่อทำคะแนนครั้งแรกในคืนนี้ของ Ovech...
# 26  ประตูที่สองของเขาในคืนนี้คือประตูที่ 60 ของฤดู...
# 27  ในรายชื่อชาวอเมริกัน 400 คนที่ร่ำรวยที่สุดในปี...
# 28  เขาจบการศึกษาจากวิทยาลับศิลปศาสตร์และวิทยาศาตร...
# 29  เรือนจำอาบูกราอิบของอิรักได้ถูกเผาในช่วงที่เกิ...
# 30  คุกดังกล่าวกลายเป็นที่โจษจันหลังพบว่ามีการล่วง...
# 31  ปิเกต์ จูเนียร์เกิดอุบัติเหตุชนในการแข่งขันสิง...
# 32  ในขณะที่รถคันต่าง ๆ ที่อยู่หน้าอลอนโซเข้าไปเติ...
# 33  ปิเกต์ จูเนียร์ถูกเชิญออกหลังจากการแข่งขันฮังก...
# 34  ณ เวลา 8.46 น. พอดิบพอดี ความเงียบปกคลุมไปทั่ว...
# 35           มีการฉายลำแสงขึ้นไปบนฟ้าสองลำตลอดทั้งคืน
# 36  ขณะนี้กำลังมีการดำเนินการก่อสร้างตึกระฟ้าแห่งใ...
# 37  รายการ PBS ได้รับรางวัล Emmy เกินยี่สิบกว่าราง...
# 38  รายการแต่ละตอนจะเน้นไปที่ประเด็นสำคัญของหนังสื...
# 39  แต่ละรายการจะแนะนำหนังสือที่เด็ก ๆ ควรมองหาเมื...
# 40  จอห์น แกรนต์ จาก WNED Buffalo (สถานีหลักของรีด...
# 41  หลายคนรวมทั้งจอห์น แกรนท์เชื่อว่าทั้งการประสบป...
# 42  นักพยากรณ์อากาศกล่าวว่า มีความเป็นไปได้ที่พายุ...
# 43  ขณะนี้พายุเฟรดมีความเร็วลมอยู่ที่ 105 ไมล์ต่อช...
# 44  เท่าที่เคยมีการบันทึกไว้ นับตั้งแต่การถือกำเนิ...
# 45  เมื่อวันที่ 24 กันยายน 1759 อาเธอร์ กินเนสส์ได...
# 46  250 ปีต่อมา กินเนสส์ได้เติบโตเป็นธุรกิจระดับโล...
# 47  Jonny Reid นักแข่งรถร่วมของทีม A1GP นิวซีแลนด์...
# 48  นาย Reid สามารถขับ Black Beauty ซึ่งเป็นรถ A1G...
# 49  ตำรวจนิวซีแลนด์เผชิญปัญหาในการใช้ปืนเรดาร์ตรวจ...
#
#                                                    vi
# 0   Vào hôm thứ Hai, các nhà khoa học thuộc Trường...
# 1   Các nhà nghiên cứu chính nói rằng điều này có ...
# 2   Chiếc JAS 39C Gripen đâm xuống đường băng vào ...
# 3   Viên phi công được xác định là Chỉ huy đội bay...
# 4   Truyền thông địa phương đưa tin một phương tiệ...
# 5   Ba mùa trước, Vidal đã rời Sevilla để gia nhập...
# 6   Từ khi chuyển đến thủ phủ của xứ Catalan, Vida...
# 7   Cuộc biểu tình bắt đầu vào khoảng 11:00 giờ sá...
# 8   Ngay sau 11 giờ những người biểu tình đã chặn ...
# 9   Vào lúc 11:20, cảnh sát đã yêu cầu người biểu ...
# 10  Khoảng 11 giờ 29 phút, nhóm biểu tình di chuyể...
# 11  Thành tích đối đầu của Nadal trước đối thủ ngư...
# 12  Gần đây anh ấy đã thua Raonic ở giải Brisbane ...
# 13  Nadal bỏ túi 88% số điểm lên lưới trong trận đ...
# 14  Sau trận đấu, Ông vua sân đất nện nói rằng “Tô...
# 15  "Hồ sơ Panama" là thuật ngữ chung cho khoảng m...
# 16  Các hồ sơ cho thấy mười bốn ngân hàng đã giúp ...
# 17  Nhật báo The Guardian của Vương quốc Anh cho r...
# 18  Biểu tình nổ ra trên toàn thế giới, một số vụ ...
# 19  Sinh trưởng ở Hồng Kông, Ma theo học Trường Đạ...
# 20  Hsieh ám chỉ trong thời gian bầu cử rằng Ma có...
# 21  Hsieh cũng lập luận rằng ông Ma lịch lãm là ki...
# 22  Bất chấp các cáo buộc này, Ma vẫn dành chiến t...
# 23  Cầu thủ xuất sắc nhất của ngày hôm nay là Alex...
# 24  Anh ấy có 2 bàn thắng và 2 bàn kiến tạo trong ...
# 25  Đường chuyền yểm trợ đầu tiên của Ovechkin đượ...
# 26  Bàn thắng thứ hai trong đêm là bàn thứ 60 của ...
# 27  Batten được xếp hạng thứ 190 trong danh sách 4...
# 28  Ông tốt nghiệp trường Nghệ thuật và Khoa học, ...
# 29  Nhà tù Abu Ghraib của Iraq đã bị đốt cháy tron...
# 30  Nhà tù này trở nên nổi tiếng kể từ vụ việc ngư...
# 31  Piquet Jr. gặp tai nạn vào năm 2008 tại Singap...
# 32  Khi những chiếc xe phía trước phải vào nạp nhi...
# 33  Piquet Jr. bị sa thải sau cuộc đua Grand Prix ...
# 34  Đúng 8 giờ 46 phút sáng, sự câm lặng bao trùm ...
# 35  Hai chùm sáng được dựng lên để thắp sáng bầu t...
# 36  Công tác thi công đang được triển khai trên cô...
# 37  Chương trình của đài PBS đã thu về hơn hai chụ...
# 38  Mỗi tập trong chương trình sẽ tập trung vào mộ...
# 39  Mỗi chương trình cũng sẽ đưa ra đề xuất về nhữ...
# 40  John Grant, đến từ WNED Buffalo (ga cơ sở của ...
# 41  Một số người, bao gồm cả John Grant, tin rằng ...
# 42  Theo thông tin dự báo thời tiết, cơn bão hiện ...
# 43  Fred hiện có sức gió 105 dặm/giờ (165 km/h) và...
# 44  Fred là gió xoáy nhiệt đới mạnh nhất từng được...
# 45  Vào 24 tháng Chín năm 1759, Arthur Guinness ký...
# 46  250 năm sau, Guinness đã phát triển thành một ...
# 47  Jonny Reid, phụ lái trong đội đua A1GP của New...
# 48  Ông Reid đã lái thành công chiếc A1GP New Zeal...
# 49  Cảnh sát New Zealand gặp khó khi sử dụng súng ...

# %% [markdown]
# # Translation

# %% [markdown]
# ### Google Translate

# %%
# Set the path to your service account key file
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "ta-msba-group-2-e04caadf49d8.json"

# Initialize the Translate API client
translator = translate.Client()

# %%
def google_translate_df(input_df, target_language):
    translated_df = pd.DataFrame()

    for col in input_df.columns:
        translated_col = []
        for cell in input_df[col]:
            # Translate each cell using Google Translate
            translation = translator.translate(cell, target_language=target_language)
            translated_text = translation['translatedText']
            translated_col.append(translated_text)
        translated_df[col] = translated_col

    return translated_df

# %%
google_candidates = google_translate_df(references.drop(columns=['en']), "en")

# %%
# Print the resulting DataFrame
google_candidates
# Out:
#                                                    hi  \
# 0   On Monday, scientists at Stanford University S...
# 1   Researchers say this could help easily identif...
# 2   At around 9:30 am local time (0230 UTC), the J...
# 3   The pilot was identified as Squadron Leader Di...
# 4   Local media has reported that the airport&#39;...
# 5   Vidal, 28, joined Barca from Sevilla three sea...
# 6   Since moving to the Catalan capital (Barcelona...
# 7   The protest began at around 11:00 am local tim...
# 8   Just after 11:00 a.m., northbound traffic on W...
# 9   At 11:20, police asked protesters to return to...
# 10  Around 11:29 am, protesters headed down Whiteh...
# 11  Nadal has a 7-2 head-to-head record against th...
# 12   He recently lost to Raonic at the Brisbane Open.
# 13  Nadal got 88% net points out of 76 match winni...
# 14  After the match, the King of Clay said, “I&#39...
# 15  The “Panama Papers” is a catchall for nearly t...
# 16  The documents reveal that fourteen banks helpe...
# 17  According to British newspaper The Guardian, D...
# 18  There were protests around the world, several ...
# 19  Ma was born in Hong Kong, studied at New York ...
# 20  During the election, Saih expressed the view t...
# 21  Shay also argued that the photogenic Ma was mo...
# 22  Despite these allegations, Ma won on a platfor...
# 23  Today&#39;s player is Alex Ovechkin of the Was...
# 24  He scored 2 goals and 2 assists in Washington&...
# 25  Ovechkin got his first assist that night on ro...
# 26  His second goal of the night was his 60th of t...
# 27  Batten was ranked 190th on the Inc. 400 riches...
# 28  He graduated from the University of Virginia’s...
# 29  Abu Ghraib prison in Iraq was set on fire duri...
# 30  The prison became notorious after prisoner abu...
# 31  Piquet Jr. crashed at the 2008 Singapore Grand...
# 32  As the cars ahead of Alonso pitted for fuel un...
# 33  Piquet Jr. was fired after the 2009 Hungarian ...
# 34  At exactly 8:46 a.m., silence descended upon t...
# 35  Two beams of light have been designed to look ...
# 36  Five new skyscrapers are in the works on the s...
# 37  This PBS show has won more than two dozen Emmy...
# 38  Each episode of the show will focus on the the...
# 39  In every show, some books will also be recomme...
# 40  John Grant from WNED Buffalo (Rainbow&#39;s ho...
# 41  Some, including John Grant, believe that both ...
# 42  Forecasters say the storm is located about 645...
# 43  Fred is currently moving northwest with winds ...
# 44  Fred is the most powerful tropical cyclone eve...
# 45  On September 24, 1759, Arthur Guinness signed ...
# 46  250 years later, Guinness has become a global ...
# 47  Today A1GP New Zealand team co-driver Jonny Re...
# 48  Mr Reid managed to take New Zealand&#39;s A1GP...
# 49  Because of the Black Beauty&#39;s small size, ...
#
#                                                    id  \
# 0   Scientists from Stanford University School of ...
# 1   The lead researcher said that this diagnosis c...
# 2   The JAS 39C Gripen crashed onto the runway at ...
# 3   The pilot was identified as Squadron Leader Di...
# 4   Local media reported that a fire extinguisher ...
# 5   The 28-year-old Vidal joined BarÃ§a three seas...
# 6   Since settling in the Catalan capital, Vidal h...
# 7   The protest began at around 11:00 local time (...
# 8   Protesters just after 11am blocked northbound ...
# 9   At 11:20 a.m., police asked the protesters to ...
# 10  At around 11.29am, the protesters moved down W...
# 11  Nadal&#39;s record against the Canadian tennis...
# 12  Recently he lost against Raonic at the Brisban...
# 13  Nadal pocketed 88% of the net points in this m...
# 14  &quot;After the match, the King of Clay said, ...
# 15  “Panama Papers” is an umbrella term for approx...
# 16  The documents show fourteen banks helped wealt...
# 17  The British newspaper The Guardian says that D...
# 18  There were worldwide protests, several crimina...
# 19  &quot;Born in Hong Kong, Ma studied at New Yor...
# 20  Hsieh implied during the election that Ma migh...
# 21  Hsieh also denied that the photogenic Ma prior...
# 22  Despite these accusations, Ma won easily on a ...
# 23  Player of the Day is Alex Ovechkin of the Wash...
# 24  He had 2 goals and 2 assists in Washington&#39...
# 25  Ovechkin&#39;s first assist of the night was o...
# 26  His second goal of the night was his 60th of t...
# 27  Batten was ranked 190th on the 2008 list of th...
# 28  He graduated from the University of Virginia C...
# 29  Iraq&#39;s Abu Ghraib prison was burned down d...
# 30  The prison became famous after abuse of prison...
# 31  Piquet Jr. crashed at the 2008 Singapore Grand...
# 32  When the car in front of Alonso refueled, he m...
# 33  Piquet Jr. fired after the 2009 Hungarian Gran...
# 34  Exactly at 08.46 in the morning, the entire ci...
# 35  Two beams of light were shone into the sky ove...
# 36  Construction of five new skyscrapers is underw...
# 37  This PBS TV show has received more than twenty...
# 38  Each episode of the show focuses on a theme in...
# 39  Each event will provide book recommendations t...
# 40  &quot;John Grant, of WNED Buffalo (Reading Rai...
# 41  John Grant and several others believe that a f...
# 42  According to forecasters, the storm about 1,04...
# 43  Fred currently has winds of 105 miles per hour...
# 44  Fred was the strongest tropical storm recorded...
# 45  Arthur Guinness signed a 9,000 year lease for ...
# 46  250 years later, Guinness has grown into a glo...
# 47  Jonny Reid, co-driver for the New Zealand A1GP...
# 48  Mr Reid successfully drove New Zealand&#39;s A...
# 49  New Zealand police had difficulty using speed ...
#
#                                                    ja  \
# 0   Scientists at the Stanford University School o...
# 1   Lead researchers say this could lead to earlie...
# 2   The JAS 39C Gripen crashed on the runway and e...
# 3   The pilot was identified as Squadron Leader Dh...
# 4   Local media reports said an airport fire truck...
# 5   The 28-year-old Vidal joined Barca from Sevill...
# 6   Since moving to the Catalan capital, Vidal has...
# 7   The protest began at around 11:00 local time (...
# 8   Just after 11am, protesters blocked northbound...
# 9   At 11:20 p.m., police asked protesters to retu...
# 10  At about 11.29pm the protesters headed towards...
# 11          Nadal&#39;s record against Canada is 7-2.
# 12  Most recently, he lost to Raonic at the Brisba...
# 13  Nadal won 76 points with his first serve durin...
# 14  After the match the King of Clay said: &quot;I...
# 15  The Panama Papers are a collective term for ap...
# 16  The documents show that 14 banks helped wealth...
# 17  Britain&#39;s Guardian newspaper suggested tha...
# 18  It sparked protests around the world, led to m...
# 19  Born in Hong Kong, Ma Ying-jeou graduated from...
# 20  During the election, Xie had hinted that Ma mi...
# 21  Hsieh Ja-ting claimed that Ma Ying-jeou looks ...
# 22  Despite these criticisms, Ma won handily by to...
# 23  Today&#39;s Player of the Day is Alex Ovechkin...
# 24  He had two goals and two assists in Washington...
# 25  Ovechkin&#39;s first assist of the night came ...
# 26  His second goal of the night was his 60th goal...
# 27  Batten was ranked 190th on the 2008 list of Am...
# 28  He graduated from the University of Virginia&#...
# 29  Iraq&#39;s Abu Ghraib prison was set on fire d...
# 30  After the US military occupation, the prison g...
# 31  Piquet Jr. crashed during the 2008 Singapore G...
# 32  As the leading cars refuelled behind the safet...
# 33  Piquet Jr. was fired after the 2009 Hungarian ...
# 34  The city fell silent at exactly 8:46 a.m. as t...
# 35  Two beams of light are positioned to point tow...
# 36  Five new skyscrapers are being constructed on ...
# 37  This PBS show has won more than 20 Emmy Awards...
# 38  Each episode of the show focused on a specific...
# 39  Each show also provided information about reco...
# 40  &quot;Reading Rainbow has given kids a reason ...
# 41  Some, including John Grant, believe that a lac...
# 42  The storm is located about 645 miles (1,040 km...
# 43  Fred is currently moving northwest with sustai...
# 44  Fred is the strongest tropical cyclone recorde...
# 45  On 24 September 1759, Arthur Guinness, founder...
# 46  250 years later, Guinness has grown into a glo...
# 47  A1GP New Zealand Team co-driver Jonny Reid mad...
# 48  Reid has driven his New Zealand A1GP car, Blac...
# 49  New Zealand police reportedly had difficulty d...
#
#                                                    ko  \
# 0   Researchers at Stanford University School of M...
# 1   Lead researchers explain that this could lead ...
# 2   At approximately 9:30 am local time (0230 UTC)...
# 3   The pilot was identified as Squadron Leader Di...
# 4   Local media reported that the airport fire tru...
# 5   Vidal, 28, joined FC Barcelona from Sevilla FC...
# 6   After moving to Barcelona, Vidal played 49 gam...
# 7   The protest began around 11:00 local time (UTC...
# 8   Just after 11 o&#39;clock, protesters blocked ...
# 9   At 11:20 police asked protesters to return to ...
# 10  At around 11:29, the protesters followed the S...
# 11  Nadal&#39;s head-to-head record against the Ca...
# 12  He recently lost to Raonic in a match at the B...
# 13  Nadal won 76 points on his first serve, achiev...
# 14  “I’m just happy to be back in the final round ...
# 15  &quot;&quot;The &quot;Panama Papers&quot;&quot...
# 16  Documents show 14 banks helped their wealthy c...
# 17  British newspaper The Guardian suggested that ...
# 18  There were protests around the world, several ...
# 19  Mr. Ma was born in Hong Kong, studied at New Y...
# 20  Hsieh hinted during the election that Ma could...
# 21  Shay also said that although Maga&#39;s photog...
# 22  Despite these accusations, Ma easily gained a ...
# 23  Today&#39;s player is Alex Ovechkin of the Was...
# 24  He had two goals and two assists in Washington...
# 25  Ovechkin&#39;s first assist of the night led t...
# 26  His second goal of the night was his 60th of t...
# 27  Mr. Batten ranked 190th in the 2008 list of 40...
# 28  He graduated from the University of Virginia i...
# 29  A fire broke out during a riot at Iraq&#39;s A...
# 30  The prison&#39;s notoriety grew when cases of ...
# 31  Piqué Jr. had an accident at the 2008 Singapor...
# 32  As the cars in front of Alonso went under the ...
# 33  Piquet Jr. was dismissed after the 2009 Hungar...
# 34  At exactly 8:46 a.m., as silence fell over the...
# 35  Two pillars of light were set up to point towa...
# 36  Five high-rise buildings, a central transporta...
# 37  The PBS show has won more than 24 Emmy Awards ...
# 38  Each episode of the show will focus on a theme...
# 39  Each show also recommends books that children ...
# 40  “Reading Rainbow taught kids why they should r...
# 41  Some, including John Grant, believe that fundi...
# 42  The storm, located about 645 miles (1,040 kilo...
# 43  Fred is currently moving northwest with winds ...
# 44  Fred is the most powerful tropical cyclone eve...
# 45  On September 24, 1759, Arthur Guinness signed ...
# 46  250 years later, Guinness has grown into a glo...
# 47  A1GP Team New Zealand co-driver Jonny Reid mad...
# 48  Mr Reid raced New Zealand&#39;s A1GP car, Blac...
# 49  New Zealand police had difficulty using the sp...
#
#                                                    es  \
# 0   On Monday, scientists at Stanford University S...
# 1   Leading senior researchers argue that this may...
# 2   The JAS 39C Gripen hit a runway around 9:30 a....
# 3   The pilot was identified as Dilokrit Pattavee,...
# 4   The local press reported that an airport fire ...
# 5   Vidal, 28 years old and from Sevilla, joined B...
# 6   Since moving to the Catalan capital, Vidal has...
# 7   The demonstration began around 11:00 local tim...
# 8   Just after 11:00 a.m., members of the demonstr...
# 9   At 11:20, police asked protesters to move back...
# 10  At around 11:29, the demonstration made its wa...
# 11  Nadal&#39;s head-to-head record against the Ca...
# 12  He was recently defeated by Raonic at the Bris...
# 13  In the match, Nadal accumulated 88% net points...
# 14  After the match, the King of Dust stated: «I a...
# 15  The generic term “Panama Papers” refers to the...
# 16  The documentation revealed that 14 banks helpe...
# 17  The British newspaper The Guardian noted that ...
# 18  Demonstrations were held worldwide, numerous c...
# 19  Ma, a native of Hong Kong, trained at New York...
# 20  During the election, Hsieh hinted that Ma coul...
# 21  Hsieh also said that the handsome Ma was more ...
# 22  Ma won a comfortable victory, despite these ac...
# 23  Alex Ovechkin, of the Washington Capitals, is ...
# 24  He scored 2 goals and 2 assists in Washington&...
# 25  Ovechkin had his first assist of the night on ...
# 26  His second score of the night was his 60th of ...
# 27  Batten reached position 190 on the list of the...
# 28  He earned his diploma in 1950 from the College...
# 29  The Abu Ghraib prison in Iraq caught fire duri...
# 30  The prison became known after prisoner abuse c...
# 31  During the 2008 Singapore Grand Prix, just aft...
# 32  When the cars ahead of Alonso stopped to refue...
# 33  After the Hungarian GP in 2009, Piquet Jr. was...
# 34  At exactly 8:46 am, the city became silent, ma...
# 35  Two beams of light were set up aimed at the sk...
# 36  Five new skyscrapers are being built on the si...
# 37  The PBS show has more than twenty-four Emmy Aw...
# 38  Each episode of the show would be developed ar...
# 39  Each episode also provided information about b...
# 40  John Grant of WNED Buffalo (Reading Rainbow&#3...
# 41  There are those who think, including John Gran...
# 42  According to meteorologists, there is a high p...
# 43  Currently, Fred&#39;s winds are reaching 105 m...
# 44  Fred is the most aggressive tropical cyclone o...
# 45  On September 24, 1759, Arthur Guinness signed ...
# 46  A quarter of a millennium later, Guinness has ...
# 47  Jonny Reid, co-driver of the New Zealand A1GP ...
# 48  Reid managed to drive the Black Beauty, New Ze...
# 49  Because of how low Black Beauty is, it was dif...
#
#                                                    th  \
# 0   last Monday Scientists at Stanford University ...
# 1   Leading researchers say this could allow for e...
# 2   The JAS 39C Gripen crashed onto the runway at ...
# 3   The pilot has been identified as Wing Commande...
# 4   Local reporters reported that airport fire tru...
# 5   Vidal, 28, joined Barca from Sevilla three sea...
# 6   Since moving to the Catalan capital Vidal has ...
# 7   The protest began around 11:00 AM local time (...
# 8   Just after 11:00 AM, protesters blocked traffi...
# 9   At 11:20 a.m., police asked protesters to move...
# 10  At about 11:29 a.m. the protest moved from Whi...
# 11  Nadal&#39;s head-to-head record against Canadi...
# 12  He recently defeated Raonic in the Brisbane Open.
# 13  Nadal took 88% of the match&#39;s points, winn...
# 14  After the competition said the clay court king...
# 15  The Panama Papers is a broad umbrella term use...
# 16  Documents suggest that 14 banks helped wealthy...
# 17  The British newspaper The Guardian hints that ...
# 18  There are protests happening all over the worl...
# 19  Ma was born in Hong Kong, studied at New York ...
# 20  Xia hinted during the election that Ma might f...
# 21  Xia also argued that Ma&#39;s photo shoot was ...
# 22  Despite these allegations But Ma easily won on...
# 23  Today&#39;s Player of the Day is Alex Ovechkin...
# 24  He scored two goals and set up two assists in ...
# 25  Ovechkin&#39;s first scoring pass of the night...
# 26  His second goal of the night was his 60th of t...
# 27  List of the 400 richest Americans in 2018 2008...
# 28  He graduated from the University of Virginia&#...
# 29  Iraq&#39;s Abu Ghraib prison burned down durin...
# 30  The prison became controversial after reports ...
# 31  Piquet Jr. crashed in the 2008 Singapore Grand...
# 32  As the cars in front of Alonso refueled under ...
# 33  Piquet Jr. was ejected after the 2009 Hungaria...
# 34  At exactly 8:46 a.m., silence enveloped the ci...
# 35  Two beams of light were projected into the sky...
# 36  Construction of five new skyscrapers is curren...
# 37  PBS programs have won over twenty Emmy Awards....
# 38  Each episode focuses on the main points of a p...
# 39  Each entry also recommends books that children...
# 40  John Grant of WNED Buffalo (Reading Rainbow&#3...
# 41  Many people, including John Grant believes tha...
# 42  The weather forecaster said It is possible tha...
# 43  Storm Fred currently has sustained winds of 10...
# 44  as ever recorded Since the advent of satellite...
# 45  On September 24, 1759, Arthur Guinness signed ...
# 46  250 years later, Guinness has grown into a glo...
# 47  A1GP Team New Zealand co-driver Jonny Reid mad...
# 48  Mr Reid was able to drive Black Beauty, a New ...
# 49  New Zealand police have struggled to use a spe...
#
#                                                    vi
# 0   On Monday, scientists at the Stanford Universi...
# 1   The lead researchers say this could help early...
# 2   The JAS 39C Gripen crashed into the runway at ...
# 3   The pilot was identified as Flight Commander D...
# 4   Local media reported that an airport firefight...
# 5   Three seasons ago, Vidal left Sevilla to join ...
# 6   Since moving to the Catalan capital, Vidal has...
# 7   The protest began at around 11:00 a.m. local t...
# 8   Just after 11am protesters blocked traffic on ...
# 9   At 11:20, police asked protesters to retreat t...
# 10  At around 11:29 a.m., the protest group moved ...
# 11  Nadal&#39;s head-to-head record against this C...
# 12    He recently lost to Raonic in the Brisbane Open
# 13  Nadal pocketed 88% of the points at the net in...
# 14  After the match, the King of Clay said, “I am ...
# 15  &quot;Panama Papers&quot; is the collective te...
# 16  Fourteen banks helped wealthy clients hide bil...
# 17  The UK daily The Guardian claims that German b...
# 18  Protests broke out worldwide, several criminal...
# 19  Born in Hong Kong, Ma studied at New York Univ...
# 20  Hsieh hinted during the election that Ma might...
# 21  Hsieh also argued that the elegant Mr. Ma is t...
# 22  Despite these accusations, Ma still scored a s...
# 23  Today&#39;s best player is Alex Ovechkin of th...
# 24  He had two goals and two assists in Washington...
# 25  Ovechkin&#39;s first cover pass was sealed by ...
# 26  His second goal of the night was his 60th this...
# 27  Batten was ranked 190th on the 2008 list of th...
# 28  He graduated from the School of Arts and Scien...
# 29  Iraq&#39;s Abu Ghraib prison was burned during...
# 30  This prison became famous since prisoner abuse...
# 31  Piquet Jr. crashed in 2008 at the Singapore Gr...
# 32  When the cars in front had to refuel at the be...
# 33  Piquet Jr. was fired after the 2009 Hungarian ...
# 34  At exactly 8:46 a.m., silence filled the city,...
# 35  Two beams of light were erected to light up th...
# 36  Construction is underway on site for five new ...
# 37  The PBS show has garnered more than two dozen ...
# 38  Each episode of the show will focus on a theme...
# 39  Each program will also make recommendations fo...
# 40  John Grant, from WNED Buffalo (Reading Rainbow...
# 41  Some, including John Grant, believe that both ...
# 42  According to weather forecasts, the storm is c...
# 43  Fred currently has winds of 105 mph (165 km/h)...
# 44  Fred is the strongest tropical cyclone recorde...
# 45  On September 24, 1759, Arthur Guinness signed ...
# 46  250 years later, Guinness has grown into a glo...
# 47  Jonny Reid, co-pilot of the New Zealand A1GP r...
# 48  Mr. Reid successfully drove the A1GP New Zeala...
# 49  New Zealand Police had difficulty using a spee...

# %% [markdown]
# ### IBM Watson Language Translator

# %%
# Defining API key and URL
with open('ibm_api.txt', 'r') as file:
    ibm_api_key = file.read()

url = 'https://api.eu-gb.language-translator.watson.cloud.ibm.com/instances/b0153ef1-fe8f-450d-b691-9abba034bcdd'

# Authenticating the API key
authenticator = IAMAuthenticator(apikey=ibm_api_key)

# Creating the Language Translator object
ibm_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator
)

# Setting the service URL
ibm_translator.set_service_url(url)
# Out:
#             On 10 June 2023, IBM announced the deprecation of the Natural Language Translator service.
#             The service will no longer be available from 8 August 2022. As of 10 June 2024, the service will reach its End of Support
#             date. As of 10 December 2024, the service will be withdrawn entirely and will no longer be
#             available to any customers.

# %%
def ibm_translate_df(input_df, target_language):
    translated_df = pd.DataFrame()

    for col in input_df.columns:
        translated_col = []
        model = col + "-" + target_language
        for cell in input_df[col]:
            # Translate each cell using Google Translate
            translation = ibm_translator.translate(
                            text = cell,
                            model_id = model
                        ).get_result()
            translated_text = translation['translations'][0]['translation']
            translated_col.append(translated_text)
        translated_df[col] = translated_col

    return translated_df

# %%
ibm_candidates = ibm_translate_df(references.drop(columns=['en']), "en")

# %% [markdown]
# ### ChatGPT

# %%
with open('chat_gpt_api.txt', 'r') as file:
    gpt_api_key = file.read()

client = OpenAI(api_key=gpt_api_key)

# %%
def chatgpt_translate_df(input_df, target_language):
    translated_df = pd.DataFrame()
    for col in input_df.columns:
        translated_col = []
        for cell in input_df[col]:
            # Translation request to OpenAI using GPT4
            response = client.chat.completions.create(
                model="gpt-4", # Change to "gpt-3.5-turbo" to run on GPT3.5
                messages=[
                    {"role": "user", "content": f"Translate the following text to {target_language}: {cell}"}
                ],
                stream=True
            )
            # Processing the streaming response
            translated_text = ''
            for chunk in response:
                if chunk.choices[0].delta.content is not None:
                    translated_text += chunk.choices[0].delta.content
            translated_col.append(translated_text)
        translated_df[col] = translated_col

    return translated_df

# %%
chatgpt_candidates = chatgpt_translate_df(references.drop(columns=['en']), "English")

# %% [markdown]
# # Tokenization

# %%
# Ensure NLTK is downloaded
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
references_tokenized = [word_tokenize(sentence) for sentence in references['en']]

# %%
def tokenize_dataframe(input_df):
    # Create a new DataFrame for tokenized strings
    tokenized_df = pd.DataFrame()

    # Tokenize strings in all columns and add them to the tokenized_df
    for col in input_df.columns:
        tokenized_df[col] = input_df[col].apply(lambda x: word_tokenize(x))

    return tokenized_df

# %%
google_candidates_tokenized = tokenize_dataframe(google_candidates)

# %%
chatgpt_candidates_tokenized = tokenize_dataframe(chatgpt_candidates)

# %%
ibm_candidates_tokenized = tokenize_dataframe(ibm_candidates)

# %%
google_candidates_tokenized
# Out:
#                                                    hi  \
# 0   [On, Monday, ,, scientists, at, Stanford, Univ...
# 1   [Researchers, say, this, could, help, easily, ...
# 2   [At, around, 9:30, am, local, time, (, 0230, U...
# 3   [The, pilot, was, identified, as, Squadron, Le...
# 4   [Local, media, has, reported, that, the, airpo...
# 5   [Vidal, ,, 28, ,, joined, Barca, from, Sevilla...
# 6   [Since, moving, to, the, Catalan, capital, (, ...
# 7   [The, protest, began, at, around, 11:00, am, l...
# 8   [Just, after, 11:00, a.m., ,, northbound, traf...
# 9   [At, 11:20, ,, police, asked, protesters, to, ...
# 10  [Around, 11:29, am, ,, protesters, headed, dow...
# 11  [Nadal, has, a, 7-2, head-to-head, record, aga...
# 12  [He, recently, lost, to, Raonic, at, the, Bris...
# 13  [Nadal, got, 88, %, net, points, out, of, 76, ...
# 14  [After, the, match, ,, the, King, of, Clay, sa...
# 15  [The, “, Panama, Papers, ”, is, a, catchall, f...
# 16  [The, documents, reveal, that, fourteen, banks...
# 17  [According, to, British, newspaper, The, Guard...
# 18  [There, were, protests, around, the, world, ,,...
# 19  [Ma, was, born, in, Hong, Kong, ,, studied, at...
# 20  [During, the, election, ,, Saih, expressed, th...
# 21  [Shay, also, argued, that, the, photogenic, Ma...
# 22  [Despite, these, allegations, ,, Ma, won, on, ...
# 23  [Today, &, #, 39, ;, s, player, is, Alex, Ovec...
# 24  [He, scored, 2, goals, and, 2, assists, in, Wa...
# 25  [Ovechkin, got, his, first, assist, that, nigh...
# 26  [His, second, goal, of, the, night, was, his, ...
# 27  [Batten, was, ranked, 190th, on, the, Inc., 40...
# 28  [He, graduated, from, the, University, of, Vir...
# 29  [Abu, Ghraib, prison, in, Iraq, was, set, on, ...
# 30  [The, prison, became, notorious, after, prison...
# 31  [Piquet, Jr., crashed, at, the, 2008, Singapor...
# 32  [As, the, cars, ahead, of, Alonso, pitted, for...
# 33  [Piquet, Jr., was, fired, after, the, 2009, Hu...
# 34  [At, exactly, 8:46, a.m., ,, silence, descende...
# 35  [Two, beams, of, light, have, been, designed, ...
# 36  [Five, new, skyscrapers, are, in, the, works, ...
# 37  [This, PBS, show, has, won, more, than, two, d...
# 38  [Each, episode, of, the, show, will, focus, on...
# 39  [In, every, show, ,, some, books, will, also, ...
# 40  [John, Grant, from, WNED, Buffalo, (, Rainbow,...
# 41  [Some, ,, including, John, Grant, ,, believe, ...
# 42  [Forecasters, say, the, storm, is, located, ab...
# 43  [Fred, is, currently, moving, northwest, with,...
# 44  [Fred, is, the, most, powerful, tropical, cycl...
# 45  [On, September, 24, ,, 1759, ,, Arthur, Guinne...
# 46  [250, years, later, ,, Guinness, has, become, ...
# 47  [Today, A1GP, New, Zealand, team, co-driver, J...
# 48  [Mr, Reid, managed, to, take, New, Zealand, &,...
# 49  [Because, of, the, Black, Beauty, &, #, 39, ;,...
#
#                                                    id  \
# 0   [Scientists, from, Stanford, University, Schoo...
# 1   [The, lead, researcher, said, that, this, diag...
# 2   [The, JAS, 39C, Gripen, crashed, onto, the, ru...
# 3   [The, pilot, was, identified, as, Squadron, Le...
# 4   [Local, media, reported, that, a, fire, exting...
# 5   [The, 28-year-old, Vidal, joined, BarÃ§a, thre...
# 6   [Since, settling, in, the, Catalan, capital, ,...
# 7   [The, protest, began, at, around, 11:00, local...
# 8   [Protesters, just, after, 11am, blocked, north...
# 9   [At, 11:20, a.m., ,, police, asked, the, prote...
# 10  [At, around, 11.29am, ,, the, protesters, move...
# 11  [Nadal, &, #, 39, ;, s, record, against, the, ...
# 12  [Recently, he, lost, against, Raonic, at, the,...
# 13  [Nadal, pocketed, 88, %, of, the, net, points,...
# 14  [&, quot, ;, After, the, match, ,, the, King, ...
# 15  [“, Panama, Papers, ”, is, an, umbrella, term,...
# 16  [The, documents, show, fourteen, banks, helped...
# 17  [The, British, newspaper, The, Guardian, says,...
# 18  [There, were, worldwide, protests, ,, several,...
# 19  [&, quot, ;, Born, in, Hong, Kong, ,, Ma, stud...
# 20  [Hsieh, implied, during, the, election, that, ...
# 21  [Hsieh, also, denied, that, the, photogenic, M...
# 22  [Despite, these, accusations, ,, Ma, won, easi...
# 23  [Player, of, the, Day, is, Alex, Ovechkin, of,...
# 24  [He, had, 2, goals, and, 2, assists, in, Washi...
# 25  [Ovechkin, &, #, 39, ;, s, first, assist, of, ...
# 26  [His, second, goal, of, the, night, was, his, ...
# 27  [Batten, was, ranked, 190th, on, the, 2008, li...
# 28  [He, graduated, from, the, University, of, Vir...
# 29  [Iraq, &, #, 39, ;, s, Abu, Ghraib, prison, wa...
# 30  [The, prison, became, famous, after, abuse, of...
# 31  [Piquet, Jr., crashed, at, the, 2008, Singapor...
# 32  [When, the, car, in, front, of, Alonso, refuel...
# 33  [Piquet, Jr., fired, after, the, 2009, Hungari...
# 34  [Exactly, at, 08.46, in, the, morning, ,, the,...
# 35  [Two, beams, of, light, were, shone, into, the...
# 36  [Construction, of, five, new, skyscrapers, is,...
# 37  [This, PBS, TV, show, has, received, more, tha...
# 38  [Each, episode, of, the, show, focuses, on, a,...
# 39  [Each, event, will, provide, book, recommendat...
# 40  [&, quot, ;, John, Grant, ,, of, WNED, Buffalo...
# 41  [John, Grant, and, several, others, believe, t...
# 42  [According, to, forecasters, ,, the, storm, ab...
# 43  [Fred, currently, has, winds, of, 105, miles, ...
# 44  [Fred, was, the, strongest, tropical, storm, r...
# 45  [Arthur, Guinness, signed, a, 9,000, year, lea...
# 46  [250, years, later, ,, Guinness, has, grown, i...
# 47  [Jonny, Reid, ,, co-driver, for, the, New, Zea...
# 48  [Mr, Reid, successfully, drove, New, Zealand, ...
# 49  [New, Zealand, police, had, difficulty, using,...
#
#                                                    ja  \
# 0   [Scientists, at, the, Stanford, University, Sc...
# 1   [Lead, researchers, say, this, could, lead, to...
# 2   [The, JAS, 39C, Gripen, crashed, on, the, runw...
# 3   [The, pilot, was, identified, as, Squadron, Le...
# 4   [Local, media, reports, said, an, airport, fir...
# 5   [The, 28-year-old, Vidal, joined, Barca, from,...
# 6   [Since, moving, to, the, Catalan, capital, ,, ...
# 7   [The, protest, began, at, around, 11:00, local...
# 8   [Just, after, 11am, ,, protesters, blocked, no...
# 9   [At, 11:20, p.m., ,, police, asked, protesters...
# 10  [At, about, 11.29pm, the, protesters, headed, ...
# 11  [Nadal, &, #, 39, ;, s, record, against, Canad...
# 12  [Most, recently, ,, he, lost, to, Raonic, at, ...
# 13  [Nadal, won, 76, points, with, his, first, ser...
# 14  [After, the, match, the, King, of, Clay, said,...
# 15  [The, Panama, Papers, are, a, collective, term...
# 16  [The, documents, show, that, 14, banks, helped...
# 17  [Britain, &, #, 39, ;, s, Guardian, newspaper,...
# 18  [It, sparked, protests, around, the, world, ,,...
# 19  [Born, in, Hong, Kong, ,, Ma, Ying-jeou, gradu...
# 20  [During, the, election, ,, Xie, had, hinted, t...
# 21  [Hsieh, Ja-ting, claimed, that, Ma, Ying-jeou,...
# 22  [Despite, these, criticisms, ,, Ma, won, handi...
# 23  [Today, &, #, 39, ;, s, Player, of, the, Day, ...
# 24  [He, had, two, goals, and, two, assists, in, W...
# 25  [Ovechkin, &, #, 39, ;, s, first, assist, of, ...
# 26  [His, second, goal, of, the, night, was, his, ...
# 27  [Batten, was, ranked, 190th, on, the, 2008, li...
# 28  [He, graduated, from, the, University, of, Vir...
# 29  [Iraq, &, #, 39, ;, s, Abu, Ghraib, prison, wa...
# 30  [After, the, US, military, occupation, ,, the,...
# 31  [Piquet, Jr., crashed, during, the, 2008, Sing...
# 32  [As, the, leading, cars, refuelled, behind, th...
# 33  [Piquet, Jr., was, fired, after, the, 2009, Hu...
# 34  [The, city, fell, silent, at, exactly, 8:46, a...
# 35  [Two, beams, of, light, are, positioned, to, p...
# 36  [Five, new, skyscrapers, are, being, construct...
# 37  [This, PBS, show, has, won, more, than, 20, Em...
# 38  [Each, episode, of, the, show, focused, on, a,...
# 39  [Each, show, also, provided, information, abou...
# 40  [&, quot, ;, Reading, Rainbow, has, given, kid...
# 41  [Some, ,, including, John, Grant, ,, believe, ...
# 42  [The, storm, is, located, about, 645, miles, (...
# 43  [Fred, is, currently, moving, northwest, with,...
# 44  [Fred, is, the, strongest, tropical, cyclone, ...
# 45  [On, 24, September, 1759, ,, Arthur, Guinness,...
# 46  [250, years, later, ,, Guinness, has, grown, i...
# 47  [A1GP, New, Zealand, Team, co-driver, Jonny, R...
# 48  [Reid, has, driven, his, New, Zealand, A1GP, c...
# 49  [New, Zealand, police, reportedly, had, diffic...
#
#                                                    ko  \
# 0   [Researchers, at, Stanford, University, School...
# 1   [Lead, researchers, explain, that, this, could...
# 2   [At, approximately, 9:30, am, local, time, (, ...
# 3   [The, pilot, was, identified, as, Squadron, Le...
# 4   [Local, media, reported, that, the, airport, f...
# 5   [Vidal, ,, 28, ,, joined, FC, Barcelona, from,...
# 6   [After, moving, to, Barcelona, ,, Vidal, playe...
# 7   [The, protest, began, around, 11:00, local, ti...
# 8   [Just, after, 11, o, &, #, 39, ;, clock, ,, pr...
# 9   [At, 11:20, police, asked, protesters, to, ret...
# 10  [At, around, 11:29, ,, the, protesters, follow...
# 11  [Nadal, &, #, 39, ;, s, head-to-head, record, ...
# 12  [He, recently, lost, to, Raonic, in, a, match,...
# 13  [Nadal, won, 76, points, on, his, first, serve...
# 14  [“, I, ’, m, just, happy, to, be, back, in, th...
# 15  [&, quot, ;, &, quot, ;, The, &, quot, ;, Pana...
# 16  [Documents, show, 14, banks, helped, their, we...
# 17  [British, newspaper, The, Guardian, suggested,...
# 18  [There, were, protests, around, the, world, ,,...
# 19  [Mr., Ma, was, born, in, Hong, Kong, ,, studie...
# 20  [Hsieh, hinted, during, the, election, that, M...
# 21  [Shay, also, said, that, although, Maga, &, #,...
# 22  [Despite, these, accusations, ,, Ma, easily, g...
# 23  [Today, &, #, 39, ;, s, player, is, Alex, Ovec...
# 24  [He, had, two, goals, and, two, assists, in, W...
# 25  [Ovechkin, &, #, 39, ;, s, first, assist, of, ...
# 26  [His, second, goal, of, the, night, was, his, ...
# 27  [Mr., Batten, ranked, 190th, in, the, 2008, li...
# 28  [He, graduated, from, the, University, of, Vir...
# 29  [A, fire, broke, out, during, a, riot, at, Ira...
# 30  [The, prison, &, #, 39, ;, s, notoriety, grew,...
# 31  [Piqué, Jr., had, an, accident, at, the, 2008,...
# 32  [As, the, cars, in, front, of, Alonso, went, u...
# 33  [Piquet, Jr., was, dismissed, after, the, 2009...
# 34  [At, exactly, 8:46, a.m., ,, as, silence, fell...
# 35  [Two, pillars, of, light, were, set, up, to, p...
# 36  [Five, high-rise, buildings, ,, a, central, tr...
# 37  [The, PBS, show, has, won, more, than, 24, Emm...
# 38  [Each, episode, of, the, show, will, focus, on...
# 39  [Each, show, also, recommends, books, that, ch...
# 40  [“, Reading, Rainbow, taught, kids, why, they,...
# 41  [Some, ,, including, John, Grant, ,, believe, ...
# 42  [The, storm, ,, located, about, 645, miles, (,...
# 43  [Fred, is, currently, moving, northwest, with,...
# 44  [Fred, is, the, most, powerful, tropical, cycl...
# 45  [On, September, 24, ,, 1759, ,, Arthur, Guinne...
# 46  [250, years, later, ,, Guinness, has, grown, i...
# 47  [A1GP, Team, New, Zealand, co-driver, Jonny, R...
# 48  [Mr, Reid, raced, New, Zealand, &, #, 39, ;, s...
# 49  [New, Zealand, police, had, difficulty, using,...
#
#                                                    es  \
# 0   [On, Monday, ,, scientists, at, Stanford, Univ...
# 1   [Leading, senior, researchers, argue, that, th...
# 2   [The, JAS, 39C, Gripen, hit, a, runway, around...
# 3   [The, pilot, was, identified, as, Dilokrit, Pa...
# 4   [The, local, press, reported, that, an, airpor...
# 5   [Vidal, ,, 28, years, old, and, from, Sevilla,...
# 6   [Since, moving, to, the, Catalan, capital, ,, ...
# 7   [The, demonstration, began, around, 11:00, loc...
# 8   [Just, after, 11:00, a.m., ,, members, of, the...
# 9   [At, 11:20, ,, police, asked, protesters, to, ...
# 10  [At, around, 11:29, ,, the, demonstration, mad...
# 11  [Nadal, &, #, 39, ;, s, head-to-head, record, ...
# 12  [He, was, recently, defeated, by, Raonic, at, ...
# 13  [In, the, match, ,, Nadal, accumulated, 88, %,...
# 14  [After, the, match, ,, the, King, of, Dust, st...
# 15  [The, generic, term, “, Panama, Papers, ”, ref...
# 16  [The, documentation, revealed, that, 14, banks...
# 17  [The, British, newspaper, The, Guardian, noted...
# 18  [Demonstrations, were, held, worldwide, ,, num...
# 19  [Ma, ,, a, native, of, Hong, Kong, ,, trained,...
# 20  [During, the, election, ,, Hsieh, hinted, that...
# 21  [Hsieh, also, said, that, the, handsome, Ma, w...
# 22  [Ma, won, a, comfortable, victory, ,, despite,...
# 23  [Alex, Ovechkin, ,, of, the, Washington, Capit...
# 24  [He, scored, 2, goals, and, 2, assists, in, Wa...
# 25  [Ovechkin, had, his, first, assist, of, the, n...
# 26  [His, second, score, of, the, night, was, his,...
# 27  [Batten, reached, position, 190, on, the, list...
# 28  [He, earned, his, diploma, in, 1950, from, the...
# 29  [The, Abu, Ghraib, prison, in, Iraq, caught, f...
# 30  [The, prison, became, known, after, prisoner, ...
# 31  [During, the, 2008, Singapore, Grand, Prix, ,,...
# 32  [When, the, cars, ahead, of, Alonso, stopped, ...
# 33  [After, the, Hungarian, GP, in, 2009, ,, Pique...
# 34  [At, exactly, 8:46, am, ,, the, city, became, ...
# 35  [Two, beams, of, light, were, set, up, aimed, ...
# 36  [Five, new, skyscrapers, are, being, built, on...
# 37  [The, PBS, show, has, more, than, twenty-four,...
# 38  [Each, episode, of, the, show, would, be, deve...
# 39  [Each, episode, also, provided, information, a...
# 40  [John, Grant, of, WNED, Buffalo, (, Reading, R...
# 41  [There, are, those, who, think, ,, including, ...
# 42  [According, to, meteorologists, ,, there, is, ...
# 43  [Currently, ,, Fred, &, #, 39, ;, s, winds, ar...
# 44  [Fred, is, the, most, aggressive, tropical, cy...
# 45  [On, September, 24, ,, 1759, ,, Arthur, Guinne...
# 46  [A, quarter, of, a, millennium, later, ,, Guin...
# 47  [Jonny, Reid, ,, co-driver, of, the, New, Zeal...
# 48  [Reid, managed, to, drive, the, Black, Beauty,...
# 49  [Because, of, how, low, Black, Beauty, is, ,, ...
#
#                                                    th  \
# 0   [last, Monday, Scientists, at, Stanford, Unive...
# 1   [Leading, researchers, say, this, could, allow...
# 2   [The, JAS, 39C, Gripen, crashed, onto, the, ru...
# 3   [The, pilot, has, been, identified, as, Wing, ...
# 4   [Local, reporters, reported, that, airport, fi...
# 5   [Vidal, ,, 28, ,, joined, Barca, from, Sevilla...
# 6   [Since, moving, to, the, Catalan, capital, Vid...
# 7   [The, protest, began, around, 11:00, AM, local...
# 8   [Just, after, 11:00, AM, ,, protesters, blocke...
# 9   [At, 11:20, a.m., ,, police, asked, protesters...
# 10  [At, about, 11:29, a.m., the, protest, moved, ...
# 11  [Nadal, &, #, 39, ;, s, head-to-head, record, ...
# 12  [He, recently, defeated, Raonic, in, the, Bris...
# 13  [Nadal, took, 88, %, of, the, match, &, #, 39,...
# 14  [After, the, competition, said, the, clay, cou...
# 15  [The, Panama, Papers, is, a, broad, umbrella, ...
# 16  [Documents, suggest, that, 14, banks, helped, ...
# 17  [The, British, newspaper, The, Guardian, hints...
# 18  [There, are, protests, happening, all, over, t...
# 19  [Ma, was, born, in, Hong, Kong, ,, studied, at...
# 20  [Xia, hinted, during, the, election, that, Ma,...
# 21  [Xia, also, argued, that, Ma, &, #, 39, ;, s, ...
# 22  [Despite, these, allegations, But, Ma, easily,...
# 23  [Today, &, #, 39, ;, s, Player, of, the, Day, ...
# 24  [He, scored, two, goals, and, set, up, two, as...
# 25  [Ovechkin, &, #, 39, ;, s, first, scoring, pas...
# 26  [His, second, goal, of, the, night, was, his, ...
# 27  [List, of, the, 400, richest, Americans, in, 2...
# 28  [He, graduated, from, the, University, of, Vir...
# 29  [Iraq, &, #, 39, ;, s, Abu, Ghraib, prison, bu...
# 30  [The, prison, became, controversial, after, re...
# 31  [Piquet, Jr., crashed, in, the, 2008, Singapor...
# 32  [As, the, cars, in, front, of, Alonso, refuele...
# 33  [Piquet, Jr., was, ejected, after, the, 2009, ...
# 34  [At, exactly, 8:46, a.m., ,, silence, envelope...
# 35  [Two, beams, of, light, were, projected, into,...
# 36  [Construction, of, five, new, skyscrapers, is,...
# 37  [PBS, programs, have, won, over, twenty, Emmy,...
# 38  [Each, episode, focuses, on, the, main, points...
# 39  [Each, entry, also, recommends, books, that, c...
# 40  [John, Grant, of, WNED, Buffalo, (, Reading, R...
# 41  [Many, people, ,, including, John, Grant, beli...
# 42  [The, weather, forecaster, said, It, is, possi...
# 43  [Storm, Fred, currently, has, sustained, winds...
# 44  [as, ever, recorded, Since, the, advent, of, s...
# 45  [On, September, 24, ,, 1759, ,, Arthur, Guinne...
# 46  [250, years, later, ,, Guinness, has, grown, i...
# 47  [A1GP, Team, New, Zealand, co-driver, Jonny, R...
# 48  [Mr, Reid, was, able, to, drive, Black, Beauty...
# 49  [New, Zealand, police, have, struggled, to, us...
#
#                                                    vi
# 0   [On, Monday, ,, scientists, at, the, Stanford,...
# 1   [The, lead, researchers, say, this, could, hel...
# 2   [The, JAS, 39C, Gripen, crashed, into, the, ru...
# 3   [The, pilot, was, identified, as, Flight, Comm...
# 4   [Local, media, reported, that, an, airport, fi...
# 5   [Three, seasons, ago, ,, Vidal, left, Sevilla,...
# 6   [Since, moving, to, the, Catalan, capital, ,, ...
# 7   [The, protest, began, at, around, 11:00, a.m.,...
# 8   [Just, after, 11am, protesters, blocked, traff...
# 9   [At, 11:20, ,, police, asked, protesters, to, ...
# 10  [At, around, 11:29, a.m., ,, the, protest, gro...
# 11  [Nadal, &, #, 39, ;, s, head-to-head, record, ...
# 12  [He, recently, lost, to, Raonic, in, the, Bris...
# 13  [Nadal, pocketed, 88, %, of, the, points, at, ...
# 14  [After, the, match, ,, the, King, of, Clay, sa...
# 15  [&, quot, ;, Panama, Papers, &, quot, ;, is, t...
# 16  [Fourteen, banks, helped, wealthy, clients, hi...
# 17  [The, UK, daily, The, Guardian, claims, that, ...
# 18  [Protests, broke, out, worldwide, ,, several, ...
# 19  [Born, in, Hong, Kong, ,, Ma, studied, at, New...
# 20  [Hsieh, hinted, during, the, election, that, M...
# 21  [Hsieh, also, argued, that, the, elegant, Mr.,...
# 22  [Despite, these, accusations, ,, Ma, still, sc...
# 23  [Today, &, #, 39, ;, s, best, player, is, Alex...
# 24  [He, had, two, goals, and, two, assists, in, W...
# 25  [Ovechkin, &, #, 39, ;, s, first, cover, pass,...
# 26  [His, second, goal, of, the, night, was, his, ...
# 27  [Batten, was, ranked, 190th, on, the, 2008, li...
# 28  [He, graduated, from, the, School, of, Arts, a...
# 29  [Iraq, &, #, 39, ;, s, Abu, Ghraib, prison, wa...
# 30  [This, prison, became, famous, since, prisoner...
# 31  [Piquet, Jr., crashed, in, 2008, at, the, Sing...
# 32  [When, the, cars, in, front, had, to, refuel, ...
# 33  [Piquet, Jr., was, fired, after, the, 2009, Hu...
# 34  [At, exactly, 8:46, a.m., ,, silence, filled, ...
# 35  [Two, beams, of, light, were, erected, to, lig...
# 36  [Construction, is, underway, on, site, for, fi...
# 37  [The, PBS, show, has, garnered, more, than, tw...
# 38  [Each, episode, of, the, show, will, focus, on...
# 39  [Each, program, will, also, make, recommendati...
# 40  [John, Grant, ,, from, WNED, Buffalo, (, Readi...
# 41  [Some, ,, including, John, Grant, ,, believe, ...
# 42  [According, to, weather, forecasts, ,, the, st...
# 43  [Fred, currently, has, winds, of, 105, mph, (,...
# 44  [Fred, is, the, strongest, tropical, cyclone, ...
# 45  [On, September, 24, ,, 1759, ,, Arthur, Guinne...
# 46  [250, years, later, ,, Guinness, has, grown, i...
# 47  [Jonny, Reid, ,, co-pilot, of, the, New, Zeala...
# 48  [Mr., Reid, successfully, drove, the, A1GP, Ne...
# 49  [New, Zealand, Police, had, difficulty, using,...

# %% [markdown]
# # Evaluation

# %%
def compute_nist_score(references, candidates_df):
    # Initialize an empty DataFrame to store the NIST scores
    nist_df = pd.DataFrame()

    # Iterate over the specified columns
    for col in candidates_df.columns:
        # Compute NIST score for each pair of sentences in the corresponding columns
        nist_scores = []
        for sent1, sent2 in zip(references, candidates_df[col]):
            nist_score = sentence_nist([sent1], sent2)
            nist_scores.append(nist_score)

        # Add NIST scores to the DataFrame
        nist_df[col] = nist_scores

        # Format the numbers as decimals
        nist_df = nist_df.applymap(lambda x: round(x, 3))

    return nist_df

# %%
google_nist = compute_nist_score(references_tokenized, google_candidates_tokenized)

# %%
chatgpt_nist = compute_nist_score(references_tokenized, chatgpt_candidates_tokenized)

# %%
ibm_nist = compute_nist_score(references_tokenized, ibm_candidates_tokenized)

# %%
ibm_nist
# Out:
#        hi     id     ja     ko     es     th     vi
# 0   3.605  3.112  2.759  2.501  3.362  3.529  3.575
# 1   2.999  3.271  2.757  3.215  3.695  2.793  3.632
# 2   2.828  3.525  3.205  2.833  3.777  2.016  3.846
# 3   2.416  3.322  0.949  1.107  2.658  1.208  2.044
# 4   1.687  1.687  0.896  2.049  2.091  1.024  1.195
# 5   2.390  2.758  1.930  1.494  2.482  1.930  1.344
# 6   2.492  2.118  2.335  3.038  2.628  2.335  3.116
# 7   2.689  2.489  1.656  1.824  2.021  2.143  2.672
# 8   1.777  2.031  1.692  1.202  1.333  2.538  1.904
# 9   2.842  2.747  2.856  3.148  3.204  3.050  2.824
# 10  1.863  3.136  2.732  1.845  3.145  2.727  3.005
# 11  2.210  1.792  1.344  1.280  2.181  1.494  1.870
# 12  2.114  2.325  1.022  2.466  1.789  2.325  2.990
# 13  2.228  2.868  2.101  1.743  2.756  2.728  2.218
# 14  3.495  3.242  3.816  2.784  3.505  3.474  3.038
# 15  3.305  3.455  2.137  2.610  2.477  2.270  3.535
# 16  2.671  3.351  2.342  2.283  2.550  3.119  2.590
# 17  3.194  3.056  2.510  2.703  2.196  2.635  1.689
# 18  3.139  2.809  2.669  1.801  2.590  2.424  2.122
# 19  3.190  3.806  2.345  3.134  3.489  2.730  3.574
# 20  1.959  2.524  1.927  1.384  2.412  2.054  3.189
# 21  2.220  2.277  1.850  0.435  2.562  1.665  1.645
# 22  2.383  2.634  1.975  2.548  2.293  2.335  2.085
# 23  1.592  2.594  3.168  1.417  2.338  2.151  2.465
# 24  3.614  3.854  2.044  2.366  3.373  1.514  3.179
# 25  1.933  2.897  1.723  1.933  2.900  1.512  2.041
# 26  3.138  4.655  2.731  3.348  4.161  3.154  4.045
# 27  2.701  2.766  2.750  2.255  2.341  2.161  2.721
# 28  3.593  3.232  3.006  2.554  2.052  3.122  3.007
# 29  1.156  1.801  1.586  1.495  2.401  2.401  1.850
# 30  1.043  1.810  0.308  1.048  2.768  1.227  1.438
# 31  2.058  3.395  2.641  2.028  2.909  2.000  2.782
# 32  3.177  1.847  1.972  3.063  2.173  1.486  2.627
# 33  2.516  3.145  1.730  2.661  1.441  2.395  3.171
# 34  2.290  2.697  2.386  1.167  1.904  2.169  2.936
# 35  1.619  1.423  0.925  1.794  1.801  1.139  1.495
# 36  1.486  2.747  2.518  2.093  2.317  2.561  2.707
# 37  1.946  2.915  1.628  3.083  2.744  3.036  2.886
# 38  3.269  3.333  1.923  2.606  3.180  1.875  2.352
# 39  1.646  2.025  2.062  1.095  1.315  1.989  2.377
# 40  3.259  3.374  2.641  2.801  3.889  3.933  4.105
# 41  3.329  2.490  2.197  2.441  3.110  2.793  3.172
# 42  3.255  3.105  2.802  2.883  2.482  1.902  3.057
# 43  2.058  3.733  1.806  1.520  2.475  2.470  2.847
# 44  3.447  3.870  2.907  3.528  2.836  2.305  3.618
# 45  4.147  3.972  2.824  3.314  4.043  3.783  4.323
# 46  3.739  3.311  3.311  3.553  2.788  3.485  3.208
# 47  3.159  3.445  2.075  3.758  3.556  2.432  3.235
# 48  2.060  2.779  2.529  2.202  3.520  2.823  3.210
# 49  2.613  3.003  2.250  2.791  3.199  2.657  3.383

# %%
google_nist
# Out:
#        hi     id     ja     ko     es     th     vi
# 0   4.905  3.957  3.420  2.860  4.133  3.958  4.472
# 1   3.468  3.490  4.372  3.481  3.588  4.173  3.875
# 2   3.525  4.006  3.722  3.979  3.949  3.059  3.846
# 3   2.990  3.322  2.658  2.658  2.416  1.812  2.658
# 4   1.434  1.898  2.151  1.673  1.280  1.103  1.870
# 5   2.689  2.987  2.841  2.049  2.390  2.689  1.344
# 6   2.829  2.010  2.628  3.038  3.116  2.552  2.872
# 7   2.908  3.420  3.086  3.568  2.131  2.710  3.126
# 8   2.991  1.896  2.709  2.115  2.464  3.046  2.862
# 9   3.170  3.202  3.175  2.224  3.265  3.455  2.499
# 10  3.113  3.621  3.325  2.876  3.313  3.450  3.411
# 11  1.870  1.673  1.494  1.792  1.536  1.536  1.434
# 12  2.658  2.325  1.938  2.300  2.114  2.818  2.818
# 13  2.895  2.868  2.479  2.392  2.676  2.186  2.834
# 14  2.997  2.844  2.926  3.063  2.825  2.951  3.226
# 15  3.155  3.535  2.472  2.148  2.768  2.804  3.159
# 16  3.491  3.951  3.400  3.171  2.644  2.899  3.109
# 17  3.628  3.056  2.510  3.594  2.703  2.928  1.969
# 18  2.673  3.779  2.121  2.919  2.740  2.132  3.219
# 19  2.979  3.271  3.246  3.487  2.740  3.082  2.942
# 20  2.372  2.815  1.927  2.652  2.412  3.621  3.267
# 21  2.846  2.101  1.088  0.881  2.846  1.586  1.448
# 22  3.871  2.919  2.658  3.196  2.383  2.414  2.293
# 23  2.299  3.488  2.559  2.299  2.268  2.770  2.027
# 24  2.730  2.924  2.530  2.725  2.924  2.657  2.725
# 25  2.366  3.119  2.791  2.046  2.369  2.096  2.012
# 26  4.397  4.905  3.509  3.489  4.292  4.014  4.198
# 27  3.382  3.733  2.624  2.947  2.701  2.593  3.285
# 28  4.094  3.691  3.121  2.976  2.495  3.471  3.231
# 29  2.562  1.480  1.959  1.645  2.401  1.480  1.480
# 30  2.687  1.900  0.632  0.682  2.442  2.821  2.438
# 31  2.785  3.863  4.090  2.787  3.443  3.117  3.447
# 32  3.395  1.042  2.763  3.294  2.763  2.321  2.367
# 33  3.145  2.996  3.145  3.145  2.018  3.145  3.145
# 34  3.299  2.286  2.185  3.224  2.652  2.458  3.151
# 35  1.850  1.794  1.727  1.619  1.586  1.423  1.993
# 36  2.795  3.403  2.948  2.361  2.479  2.933  3.161
# 37  2.066  2.728  1.676  2.842  2.668  1.957  3.011
# 38  3.652  3.543  3.449  3.896  2.906  2.664  3.545
# 39  1.572  2.047  2.927  1.368  2.062  2.239  2.702
# 40  3.583  2.809  2.775  3.198  2.830  3.025  3.824
# 41  3.606  2.828  2.326  2.637  3.073  2.616  2.794
# 42  3.561  3.291  3.523  2.822  2.422  2.457  3.207
# 43  2.439  4.124  2.957  1.672  2.593  3.458  3.285
# 44  4.656  4.025  3.884  3.998  3.492  2.835  3.234
# 45  3.489  3.727  2.819  3.619  3.489  3.947  3.758
# 46  3.800  3.659  3.217  3.366  2.577  3.446  3.011
# 47  3.162  4.241  2.790  2.896  3.602  3.561  3.332
# 48  3.076  2.498  3.017  3.306  2.749  2.999  3.019
# 49  2.581  3.718  2.191  3.628  3.222  3.086  3.167

# %%
def calculate_stats(df):
    # Calculate mean and standard deviation for each column
    mean_values = df.mean()
    std_values = df.std()

    # Create a DataFrame to store the results
    stats_df = pd.DataFrame({'variable': ['mean', 'sd']})

    # Add mean and standard deviation values for each column
    for col in df.columns:
        stats_df[col] = [mean_values[col], std_values[col]]

    return stats_df

# %%
google_nist_stats = calculate_stats(google_nist)

# %%
chatgpt_nist_stats = calculate_stats(chatgpt_nist)

# %%
ibm_nist_stats = calculate_stats(ibm_nist)

# %%
google_nist_stats
# Out:
#   variable        hi        id        ja        ko        es        th  \
# 0     mean  3.049720  3.056160  2.729600  2.732060  2.739000  2.771060
# 1       sd  0.710089  0.823771  0.723953  0.774174  0.608404  0.696462
#
#          vi
# 0  2.902040
# 1  0.704929

# %%
# Extract mean values and standard deviations
means = google_nist_stats.loc[google_nist_stats['variable'] == 'mean'].drop(columns='variable').iloc[0]
stds = google_nist_stats.loc[google_nist_stats['variable'] == 'sd'].drop(columns='variable').iloc[0]

# Plot
plt.figure(figsize=(10, 6))
plt.bar(means.index, means, yerr=stds, capsize=5)
plt.title('Mean and SD')
plt.xlabel('Language')
plt.ylabel('BLEU score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Set up bootstrapping functions

# %%
# Bootstrap replicates function
def bootstrap_replicate_1d(data, func):
    """Generate bootstrap replicate of 1D data."""
    bs_sample = np.random.choice(data, len(data))
    return func(bs_sample)

def draw_bs_reps(data, func, size=1):
    """Draw bootstrap replicates."""
    # Initialize array of replicates: bs_replicates
    bs_replicates = np.empty(size)

    # Generate replicates
    for i in range(size):
        bs_replicates[i] = bootstrap_replicate_1d(data, func)

    return bs_replicates

# %%
def calculate_mean(df):
    # Calculate mean for each column
    mean_values = df.mean()
    # Create a DataFrame to store the results
    mean_df = pd.DataFrame({'variable': ['mean']})
    # Add mean and standard deviation values for each column
    for col in df.columns:
        mean_df[col] = [mean_values[col]]
    return mean_df

# %% [markdown]
# ## Google Translate vs. IBM

# %% [markdown]
# ### Bootstrapping

# %%
google_means = google_nist_stats.iloc[0,1:]
ibm_means = ibm_nist_stats.iloc[0,1:]
# Difference in means of Google vs. IBM
diff_means_ggl_ibm = google_means - ibm_means

# Calculate mean of all NIST scores of the two systems
mean_ggl_ibm = (google_means + ibm_means) / 2

# Create shifted data sets: original_data - data_mean + pair_mean
google_ibm_shifted = google_nist - google_means + mean_ggl_ibm
ibm_google_shifted = ibm_nist - ibm_means + mean_ggl_ibm

# Generate bootstrap replicates
bootstrap_size = 5000
 # Google bootstrap
google_ibm_bs = []

for col in google_ibm_shifted.columns:
  bs_reps = draw_bs_reps(google_ibm_shifted[col], np.mean, size = bootstrap_size)
  google_ibm_bs.append(bs_reps)
 # Combine all Series into a DataFrame
google_ibm_bs = pd.DataFrame(google_ibm_bs).transpose()
google_ibm_bs.columns = google_ibm_shifted.columns #rename columns

 # IBM bootstrap
ibm_google_bs = []

for col in ibm_google_shifted.columns:
  bs_reps = draw_bs_reps(ibm_google_shifted[col], np.mean, size = bootstrap_size)
  ibm_google_bs.append(bs_reps)
 # Combine all Series into a DataFrame
ibm_google_bs = pd.DataFrame(ibm_google_bs).transpose()
ibm_google_bs.columns = ibm_google_shifted.columns #rename columns

# %% [markdown]
# ### Print Result

# %%
# Calculate diference in means of the bootstrap replicates
bs_rep_ggl_ibm = google_ibm_bs - ibm_google_bs

# Compute p-Value
p_ggl_higher_ibm = np.sum(bs_rep_ggl_ibm > diff_means_ggl_ibm) / len(bs_rep_ggl_ibm)
p_ggl_lower_ibm = np.sum(bs_rep_ggl_ibm < diff_means_ggl_ibm) / len(bs_rep_ggl_ibm)

#Construct evaluation result
bs_rep_ggl_ibm_mean = calculate_mean(bs_rep_ggl_ibm)
bs_rep_ggl_ibm_mean.insert(0, 'h0', 'google - ibm', True)

p_ggl_higher_ibm = pd.DataFrame(p_ggl_higher_ibm).transpose() #rename(index = {0:'p-value'})
p_ggl_higher_ibm.insert(0, 'h0', 'google > ibm', True)
p_ggl_higher_ibm.insert(1, 'variable', 'p-higher', True)

p_ggl_lower_ibm = pd.DataFrame(p_ggl_lower_ibm).transpose()
p_ggl_lower_ibm.insert(0, 'h0', 'google < ibm', True)
p_ggl_lower_ibm.insert(1, 'variable', 'p-lower', True)

pd.concat([bs_rep_ggl_ibm_mean, p_ggl_higher_ibm, p_ggl_lower_ibm], ignore_index = True)
# Out:
#              h0  variable        hi        id       ja       ko        es  \
# 0  google - ibm      mean -0.001479  0.001654  0.00133  0.00179 -0.001604
# 1  google > ibm  p-higher  0.000600  0.136200  0.00000  0.00320  0.384800
# 2  google < ibm   p-lower  0.999400  0.863800  1.00000  0.99680  0.615200
#
#          th        vi
# 0  0.000783  0.002529
# 1  0.002200  0.162200
# 2  0.997800  0.837600

# %% [markdown]
# Google vs. IBM:
# - Not really different from each other: hi, ko
# - Google is better than IBM: es
# - IBM is better: id, ja, th, vi

# %% [markdown]
# ## IBM vs. ChatGPT

# %% [markdown]
# ### Bootstrapping

# %%
chatgpt_means = chatgpt_nist_stats.iloc[0,1:]
ibm_means = ibm_nist_stats.iloc[0,1:]
# Difference in means of IBM vs. ChatGPT
diff_means_ibm_chatgpt = ibm_means - chatgpt_means

# Calculate mean of all NIST scores of the two systems
mean_ibm_chatgpt = (chatgpt_means + ibm_means) / 2

# Create shifted data sets: original_data - data_mean + pair_mean
chatgpt_ibm_shifted = chatgpt_nist - chatgpt_means + mean_ibm_chatgpt
ibm_chatgpt_shifted = ibm_nist - ibm_means + mean_ibm_chatgpt

# Generate bootstrap replicates
bootstrap_size = 5000
 # ChatGPT bootstrap
chatgpt_ibm_bs = []

for col in chatgpt_ibm_shifted.columns:
  bs_reps = draw_bs_reps(chatgpt_ibm_shifted[col], np.mean, size = bootstrap_size)
  chatgpt_ibm_bs.append(bs_reps)
 # Combine all Series into a DataFrame
chatgpt_ibm_bs = pd.DataFrame(chatgpt_ibm_bs).transpose()
chatgpt_ibm_bs.columns = chatgpt_ibm_shifted.columns #rename columns

 # IBM bootstrap
ibm_chatgpt_bs = []

for col in ibm_chatgpt_shifted.columns:
  bs_reps = draw_bs_reps(ibm_chatgpt_shifted[col], np.mean, size = bootstrap_size)
  ibm_chatgpt_bs.append(bs_reps)
 # Combine all Series into a DataFrame
ibm_chatgpt_bs = pd.DataFrame(ibm_chatgpt_bs).transpose()
ibm_chatgpt_bs.columns = ibm_chatgpt_shifted.columns #rename columns

# %% [markdown]
# ### Print Result

# %%
# Calculate diference in means of the bootstrap replicates
bs_rep_ibm_chatgpt = ibm_chatgpt_bs - chatgpt_ibm_bs

# Compute p-Value
p_ibm_higher_chatgpt = np.sum(bs_rep_ibm_chatgpt > diff_means_ibm_chatgpt) / len(bs_rep_ibm_chatgpt)
p_ibm_lower_chatgpt = np.sum(bs_rep_ibm_chatgpt < diff_means_ibm_chatgpt) / len(bs_rep_ibm_chatgpt)

#Construct evaluation result
bs_rep_ibm_chatgpt_mean = calculate_mean(bs_rep_ibm_chatgpt)
bs_rep_ibm_chatgpt_mean.insert(0, 'h0', 'ibm-chatgpt', True)

p_ibm_higher_chatgpt = pd.DataFrame(p_ibm_higher_chatgpt).transpose()
p_ibm_higher_chatgpt.insert(0, 'h0', 'ibm > chatgpt', True)
p_ibm_higher_chatgpt.insert(1, 'variable', 'p-higher', True)

p_ibm_lower_chatgpt = pd.DataFrame(p_ibm_lower_chatgpt).transpose()
p_ibm_lower_chatgpt.insert(0, 'h0', 'ibm < chatgpt', True)
p_ibm_lower_chatgpt.insert(1, 'variable', 'p-lower', True)

pd.concat([bs_rep_ibm_chatgpt_mean, p_ibm_higher_chatgpt, p_ibm_lower_chatgpt], ignore_index = True)
# Out:
#               h0  variable        hi        id        ja        ko        es  \
# 0    ibm-chatgpt      mean -0.000924 -0.000511  0.003315 -0.000665 -0.001463
# 1  ibm > chatgpt  p-higher  0.919000  0.841200  0.968600  0.994400  0.631800
# 2  ibm < chatgpt   p-lower  0.081000  0.158800  0.031400  0.005600  0.368200
#
#          th        vi
# 0  0.003011  0.001112
# 1  0.914400  0.891400
# 2  0.085600  0.108600

# %% [markdown]
# ## ChatGPT vs. Google Translate

# %% [markdown]
# ### Bootstrapping

# %%
chatgpt_means = chatgpt_nist_stats.iloc[0,1:]
google_means = google_nist_stats.iloc[0,1:]
# Difference in means of ChatGPT vs. Google Translate
diff_means_chatgpt_google = chatgpt_means - google_means

# Calculate mean of all NIST scores of the two systems
mean_chatgpt_google = (chatgpt_means + google_means) / 2

# Create shifted data sets: original_data - data_mean + pair_mean
chatgpt_google_shifted = chatgpt_nist - chatgpt_means + mean_chatgpt_google
google_chatgpt_shifted = google_nist - google_means + mean_chatgpt_google

# Generate bootstrap replicates
bootstrap_size = 5000
 # ChatGPT bootstrap
chatgpt_google_bs = []

for col in chatgpt_google_shifted.columns:
  bs_reps = draw_bs_reps(chatgpt_google_shifted[col], np.mean, size = bootstrap_size)
  chatgpt_google_bs.append(bs_reps)
 # Combine all Series into a DataFrame
chatgpt_google_bs = pd.DataFrame(chatgpt_google_bs).transpose()
chatgpt_google_bs.columns = chatgpt_google_shifted.columns #rename columns

 # Google bootstrap
google_chatgpt_bs = []

for col in google_chatgpt_shifted.columns:
  bs_reps = draw_bs_reps(google_chatgpt_shifted[col], np.mean, size = bootstrap_size)
  google_chatgpt_bs.append(bs_reps)
 # Combine all Series into a DataFrame
google_chatgpt_bs = pd.DataFrame(google_chatgpt_bs).transpose()
google_chatgpt_bs.columns = google_chatgpt_shifted.columns #rename columns

# %% [markdown]
# ### Print Result

# %%
# Calculate diference in means of the bootstrap replicates
bs_rep_chatgpt_google = chatgpt_google_bs - google_chatgpt_bs

# Compute p-Value
p_chatgpt_higher_google = np.sum(bs_rep_chatgpt_google > diff_means_chatgpt_google) / len(bs_rep_chatgpt_google)
p_chatgpt_lower_google = np.sum(bs_rep_chatgpt_google < diff_means_chatgpt_google) / len(bs_rep_chatgpt_google)

#Construct evaluation result
bs_rep_chatgpt_google_mean = calculate_mean(bs_rep_chatgpt_google)
bs_rep_chatgpt_google_mean.insert(0, 'h0', 'chatgpt-google', True)

p_chatgpt_higher_google = pd.DataFrame(p_chatgpt_higher_google).transpose()
p_chatgpt_higher_google.insert(0, 'h0', 'chatgpt > google', True)
p_chatgpt_higher_google.insert(1, 'variable', 'p-higher', True)

p_chatgpt_lower_google = pd.DataFrame(p_chatgpt_lower_google).transpose()
p_chatgpt_lower_google.insert(0, 'h0', 'chatgpt < google', True)
p_chatgpt_lower_google.insert(1, 'variable', 'p-lower', True)

pd.concat([bs_rep_chatgpt_google_mean, p_chatgpt_higher_google, p_chatgpt_lower_google], ignore_index = True)
# Out:
#                  h0  variable        hi        id        ja        ko  \
# 0    chatgpt-google      mean -0.001762  0.001585  0.005624 -0.004018
# 1  chatgpt > google  p-higher  0.962000  0.548600  0.971400  0.602400
# 2  chatgpt < google   p-lower  0.038000  0.451400  0.028600  0.397600
#
#          es        th        vi
# 0  0.000984 -0.002288 -0.002802
# 1  0.473600  0.911800  0.395000
# 2  0.526400  0.088200  0.605000

# %% [markdown]
# ## Put them all together

# %%
pd.concat([bs_rep_ggl_ibm_mean, p_ggl_higher_ibm, p_ggl_lower_ibm,
           bs_rep_ibm_chatgpt_mean, p_ibm_higher_chatgpt, p_ibm_lower_chatgpt,
           bs_rep_chatgpt_google_mean, p_chatgpt_higher_google, p_chatgpt_lower_google], ignore_index = True)
# Out:
#                  h0  variable        hi        id        ja        ko  \
# 0      google - ibm      mean -0.001479  0.001654  0.001330  0.001790
# 1      google > ibm  p-higher  0.000600  0.136200  0.000000  0.003200
# 2      google < ibm   p-lower  0.999400  0.863800  1.000000  0.996800
# 3       ibm-chatgpt      mean -0.000924 -0.000511  0.003315 -0.000665
# 4     ibm > chatgpt  p-higher  0.919000  0.841200  0.968600  0.994400
# 5     ibm < chatgpt   p-lower  0.081000  0.158800  0.031400  0.005600
# 6    chatgpt-google      mean -0.001762  0.001585  0.005624 -0.004018
# 7  chatgpt > google  p-higher  0.962000  0.548600  0.971400  0.602400
# 8  chatgpt < google   p-lower  0.038000  0.451400  0.028600  0.397600
#
#          es        th        vi
# 0 -0.001604  0.000783  0.002529
# 1  0.384800  0.002200  0.162200
# 2  0.615200  0.997800  0.837600
# 3 -0.001463  0.003011  0.001112
# 4  0.631800  0.914400  0.891400
# 5  0.368200  0.085600  0.108600
# 6  0.000984 -0.002288 -0.002802
# 7  0.473600  0.911800  0.395000
# 8  0.526400  0.088200  0.605000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['hi'].plot(kind='hist', bins=20, title='hi')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['id'].plot(kind='hist', bins=20, title='id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['ja'].plot(kind='hist', bins=20, title='ja')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('variable').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='index', y='hi', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='hi', y='id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='id', y='ja', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='ja', y='ko', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['hi']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('variable')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='variable', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('hi')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('variable')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='variable', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['ja']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('variable')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='variable', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('ja')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['ko']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('variable')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='variable', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('ko')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['hi'].plot(kind='line', figsize=(8, 4), title='hi')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['id'].plot(kind='line', figsize=(8, 4), title='id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['ja'].plot(kind='line', figsize=(8, 4), title='ja')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['variable'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='index', y='variable', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['variable'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='hi', y='variable', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['variable'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='id', y='variable', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['variable'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='ja', y='variable', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
